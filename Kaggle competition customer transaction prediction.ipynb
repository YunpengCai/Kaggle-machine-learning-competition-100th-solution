# %% [markdown]
# ## Santander Customer Transaction Prediction

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.preprocessing import MinMaxScaler, StandardScaler, scale
from sklearn.metrics import roc_auc_score

# %%
train=pd.read_csv('train.csv')

# %%
test=pd.read_csv('test.csv')

# %%
features=[c for c in train.columns if c not in ['ID_code', 'target']]

# %%
train.head()
# Out:
#      var_0   var_1    var_2   var_3    var_4   var_5   var_6    var_7   var_8  \
# 0   8.9255 -6.7863  11.9081  5.0930  11.4607 -9.2834  5.1187  18.6266 -4.9200
# 1  11.5006 -4.1473  13.8588  5.3890  12.3622  7.0433  5.6208  16.5338  3.1468
# 2   8.6093 -2.7457  12.0805  7.8928  10.5825 -9.0837  6.9427  14.6155 -4.9193
# 3  11.0604 -2.1518   8.9522  7.1957  12.5846 -1.8361  5.8428  14.9250 -5.8609
# 4   9.8369 -1.4834  12.8746  6.6375  12.2772  2.4486  5.9405  19.2514  6.2654
#
#     var_9      ...       log10_var_197  r1_var_198  r2_var_198   exp_var_198  \
# 0  5.7470      ...            0.932651        12.8       12.78  3.551516e+05
# 1  8.0851      ...            0.943935        18.4       18.36  9.373667e+07
# 2  5.9525      ...            0.917374        14.7       14.72  2.476112e+06
# 3  8.2450      ...            1.012508        18.0       17.97  6.370031e+07
# 4  7.6784      ...            0.977865        18.0       18.00  6.548947e+07
#
#    tanh_var_198  log10_var_198  r1_var_199  r2_var_199  exp_var_199  \
# 0           1.0       1.106541        -1.1       -1.09     0.335746
# 1           1.0       1.263778         2.0        1.95     7.041351
# 2           1.0       1.167973         0.4        0.40     1.486612
# 3           1.0       1.254541        -9.0       -9.00     0.000123
# 4           1.0       1.255210        -8.8       -8.81     0.000149
#
#    tanh_var_199
# 0     -0.797389
# 1      0.960459
# 2      0.376950
# 3     -1.000000
# 4     -1.000000
#
# [5 rows x 1069 columns]

# %%
test.head()
# Out:
#   ID_code    var_0    var_1    var_2   var_3    var_4   var_5   var_6  \
# 0  test_0  11.0656   7.7798  12.9536  9.4292  11.4327 -2.3805  5.8493
# 1  test_1   8.5304   1.2543  11.3047  5.1858   9.1974 -4.0117  6.0196
# 2  test_2   5.4827 -10.3581  10.1407  7.0479  10.2628  9.8052  4.8950
# 3  test_3   8.5374  -1.3222  12.0220  6.5749   8.8458  3.1744  4.9397
# 4  test_4  11.7058  -0.1327  14.1295  7.7506   9.1035 -8.5848  6.8595
#
#      var_7   var_8   ...     var_190  var_191  var_192  var_193  var_194  \
# 0  18.2675  2.1337   ...     -2.1556  11.8495  -1.4300   2.4508  13.7112
# 1  18.6316 -4.4131   ...     10.6165   8.8349   0.9403  10.1282  15.5765
# 2  20.2537  1.5233   ...     -0.7484  10.9935   1.9803   2.1800  12.9813
# 3  20.5660  3.3755   ...      9.5702   9.0766   1.6580   3.5813  15.1874
# 4  10.6048  2.9890   ...      4.2259   9.1723   1.2835   3.3778  19.5542
#
#    var_195  var_196  var_197  var_198  var_199
# 0   2.4669   4.3654  10.7200  15.4722  -8.7197
# 1   0.4773  -1.4852   9.8714  19.1293 -20.9760
# 2   2.1281  -7.1086   7.0618  19.8956 -23.1794
# 3   3.1656   3.9567   9.2295  13.0168  -4.2108
# 4  -0.2860  -5.1612   7.2882  13.9260  -9.1846
#
# [5 rows x 201 columns]

# %% [markdown]
# ## Data exploration analysis
# - Thanks to Santander EDA and Prediction from Gabriel Preda (https://www.kaggle.com/gpreda/santander-eda-and-prediction)
# - No missing data in both train and test datasets
# - Standard deviation is relatively large for both train and test variable data, mean values are distributed over a large range
# - Only 10 % train data with a target value of 1
# - Barely no correlation among features
# - Var 68, 313, 126 have duplicated values of about 1000, 300, 300, respectively.

# %% [markdown]
# ## Feature engineering

# %% [markdown]
# #### Add the polynominal feature columns up to power of 4, add root and rounded feature columns

# %%
for feature in features:
    #train['mean_'+feature] = (train[feature].mean()-train[feature])
    #train['z_'+feature] = (train[feature] - train[feature].mean())/train[feature].std(ddof=0)
    #train['sq_'+feature] = (train[feature])**2
    #train['sqrt_'+feature] = np.abs(train[feature])**(1/2)
    #train['c_'+feature] = (train[feature])**3
    #train['p4_'+feature] = (train[feature])**4
    train['r1_'+feature] = np.round(train[feature], 1)
    train['r2_'+feature] = np.round(train[feature], 2)
    train['exp_'+feature]=np.exp(train[feature])
    train['tanh_'+feature]=np.tanh(train[feature])
    if train[feature].min()>0:
        train['log10_'+feature]=np.log10(train[feature])

# %%
for feature in features:
    # test['mean_'+feature] = (train[feature].mean()-test[feature])
    # test['z_'+feature] = (test[feature] - train[feature].mean())/train[feature].std(ddof=0)
    #test['sq_'+feature] = (test[feature])**2
    #test['sqrt_'+feature] = np.abs(test[feature])**(1/2)
    #test['c_'+feature] = (test[feature])**3
    #test['p4_'+feature] = (test[feature])**4
    test['r1_'+feature] = np.round(test[feature], 1)
    test['r2_'+feature] = np.round(test[feature], 2)
    test['exp_'+feature]=np.exp(test[feature])
    test['tanh_'+feature]=np.tanh(test[feature])
    if test[feature].min()>0:
        test['log10_'+feature]=np.log10(test[feature])

# %%
y=train['target']
X = train.drop(['target', 'ID_code'], axis=1)

# %%
sc = StandardScaler()
X= sc.fit_transform(X)
X_train, X_valid, y_train, y_valid = train_test_split(X, y, stratify=y, test_size=0.2, random_state=42)

# %%
X_train.shape, X_valid.shape, y_train.shape, y_valid.shape
# Out:
# ((160000, 200), (40000, 200), (160000,), (40000,))

# %%
X_test = test.drop(['ID_code'],axis = 1)
X_test= sc.fit_transform(X_test)

# %%
#sc = StandardScaler()
#X= sc.fit_transform(X)
#X_test = sc.transform(X_test)
n_splits = 5 # Number of K-fold Splits

splits = list(StratifiedKFold(n_splits=n_splits, shuffle=True).split(X, y))

# %% [markdown]
# ## Classification models

# %% [markdown]
# ### LightGBM

# %%
import lightgbm as lgb

# %%
train_data = lgb.Dataset(X_train, label=y_train)
validation_data = lgb.Dataset(X_valid, label=y_valid)

# %%
lgb_param = {
        'num_leaves': 6,
        'max_bin': 63,
        'min_data_in_leaf': 45,
        'learning_rate': 0.01,
        'min_sum_hessian_in_leaf': 0.000446,
        'bagging_fraction': 0.55, 
        'bagging_freq': 5, 
        'max_depth': 14,
        'save_binary': True,
        'seed': 42,
        'feature_fraction_seed': 31415,
         'feature_fraction': 0.51,
        'bagging_seed': 42,
        'drop_seed': 42,
        'data_random_seed': 42,
        'objective': 'binary',
        'boosting_type': 'gbdt',
        'verbose': 1,
        'metric': 'auc',
        'is_unbalance': True,
        'boost_from_average': False,
    }

# %%
num_round = 15000
lgb_clf = lgb.train(param, train_data, num_round, valid_sets=[validation_data],verbose_eval=1000, early_stopping_rounds = 250)
# Out:
# Training until validation scores don't improve for 250 rounds.
# [1000]	valid_0's auc: 0.847525
# [2000]	valid_0's auc: 0.872533
# [3000]	valid_0's auc: 0.883519
# [4000]	valid_0's auc: 0.889354
# [5000]	valid_0's auc: 0.89292
# [6000]	valid_0's auc: 0.894756
# [7000]	valid_0's auc: 0.896039
# [8000]	valid_0's auc: 0.896756
# [9000]	valid_0's auc: 0.897017
# Early stopping, best iteration is:
# [9605]	valid_0's auc: 0.897263

# %% [markdown]
# #### With exp, tanh and log10, auc got slightly higher (0.8972>0.8969)

# %%
lgb_clf.save_model('exp_tanh_lgb_clf.txt')
# lgb = lgb.Booster(model_file='lgb_clf.txt')

# %%
importance_df = pd.DataFrame()
new_features=[c for c in train.columns]
importance_df["feature"] = new_features
importance_df["importance"] = lgb_clf.feature_importance()

# %%
pd.options.display.max_rows=500
importance_df.sort_values(by=['importance'], ascending=False)[:500]
# Out:
#             feature  importance
# 610       r1_var_94         163
# 432       r1_var_53         156
# 680    tanh_var_109         151
# 205        r1_var_1         143
# 597       r2_var_91         143
# 297     tanh_var_21         140
# 604     tanh_var_92         139
# 1030     r1_var_191         137
# 298       r1_var_22         136
# 228        r2_var_6         134
# 166         var_166         133
# 806      r1_var_139         133
# 12           var_12         132
# 133         var_133         128
# 448     tanh_var_56         128
# 727      r1_var_121         125
# 352       r2_var_34         125
# 556     tanh_var_81         125
# 911      r1_var_163         123
# 1028    exp_var_190         123
# 675    tanh_var_108         123
# 915      r1_var_164         122
# 961    tanh_var_174         120
# 530     tanh_var_75         120
# 34           var_34         120
# 942      r1_var_170         119
# 782      r2_var_133         119
# 6             var_6         118
# 494       r1_var_67         118
# 541       r2_var_78         116
# 241        r1_var_9         116
# 148         var_148         115
# 925      r2_var_166         115
# 108         var_108         114
# 259       r1_var_13         114
# 846      r2_var_148         114
# 632       r2_var_99         113
# 151         var_151         113
# 169         var_169         112
# 349     tanh_var_33         111
# 531       r1_var_76         111
# 147         var_147         111
# 283       r2_var_18         110
# 125         var_125         110
# 303       r2_var_23         109
# 209        r1_var_2         109
# 415       r1_var_49         109
# 922    tanh_var_165         108
# 540       r1_var_78         108
# 631       r1_var_99         107
# 394       r1_var_44         106
# 376       r1_var_40         106
# 242        r2_var_9         106
# 206        r2_var_1         105
# 872      r1_var_154         105
# 80           var_80         104
# 411       r1_var_48         104
# 919      r1_var_165         104
# 885      r1_var_157         103
# 53           var_53         102
# 146         var_146         102
# 198         var_198         102
# 433       r2_var_53         102
# 974    tanh_var_177         102
# 1001     r1_var_184         101
# 533      exp_var_76         100
# 36           var_36         100
# 121         var_121          99
# 958      r1_var_174          99
# 316       r1_var_26          99
# 299       r2_var_22          98
# 71           var_71          98
# 76           var_76          98
# 110         var_110          98
# 874     exp_var_154          98
# 255       r2_var_12          97
# 9             var_9          97
# 91           var_91          96
# 513      exp_var_71          96
# 1020   tanh_var_188          96
# 837      r2_var_146          95
# 223        r1_var_5          94
# 33           var_33          94
# 1003    exp_var_184          93
# 227        r1_var_6          93
# 758      r1_var_128          93
# 130         var_130          93
# 938      r2_var_169          93
# 210        r2_var_2          92
# 262     tanh_var_13          92
# 347       r2_var_33          91
# 816     exp_var_141          91
# 588       r1_var_89          91
# 962      r1_var_175          91
# 88           var_88          91
# 1047     r1_var_195          90
# 170         var_170          90
# 81           var_81          90
# 728      r2_var_121          89
# 99           var_99          89
# 204     log10_var_0          89
# 756     exp_var_127          89
# 852     exp_var_149          88
# 118         var_118          88
# 971      r1_var_177          88
# 342       r1_var_32          88
# 179         var_179          88
# 953    tanh_var_172          88
# 122         var_122          87
# 980      r1_var_179          87
# 197         var_197          87
# 767      r1_var_130          87
# 26           var_26          87
# 1056     r2_var_197          86
# 606       r2_var_93          86
# 356       r1_var_35          86
# 808     exp_var_139          86
# 127         var_127          86
# 551      exp_var_80          86
# 43           var_43          85
# 78           var_78          85
# 269       r2_var_15          85
# 184         var_184          84
# 174         var_174          84
# 601       r1_var_92          84
# 22           var_22          84
# 755      r2_var_127          84
# 300      exp_var_22          84
# 1063   tanh_var_198          83
# 773      r2_var_131          83
# 40           var_40          83
# 95           var_95          83
# 190         var_190          82
# 663      r1_var_106          82
# 774     exp_var_131          82
# 984      r1_var_180          82
# 115         var_115          82
# 737      r2_var_123          82
# 577      exp_var_86          82
# 107         var_107          81
# 836      r1_var_146          81
# 709     exp_var_116          81
# 705     exp_var_115          81
# 351       r1_var_34          81
# 664      r2_var_106          81
# 109         var_109          81
# 1026     r1_var_190          81
# 944     exp_var_170          81
# 955      r2_var_173          81
# 111         var_111          80
# 732      r1_var_122          79
# 378      exp_var_40          79
# 123         var_123          79
# 132         var_132          79
# 960     exp_var_174          79
# 23           var_23          79
# 67           var_67          78
# 295       r2_var_21          78
# 615       r1_var_95          77
# 633      exp_var_99          77
# 886      r2_var_157          77
# 1031     r2_var_191          77
# 877      r2_var_155          77
# 542      exp_var_78          77
# 745      r2_var_125          77
# 734     exp_var_122          76
# 691      r1_var_112          76
# 445       r1_var_56          76
# 250       r1_var_11          76
# 878     exp_var_155          76
# 1034     r1_var_192          76
# 144         var_144          76
# 857    tanh_var_150          75
# 89           var_89          75
# 362      exp_var_36          75
# 558       r1_var_82          75
# 35           var_35          75
# 495       r2_var_67          75
# 1027     r2_var_190          75
# 682      r1_var_110          75
# 5             var_5          74
# 717     exp_var_118          74
# 929      r1_var_167          74
# 192         var_192          74
# 611       r2_var_94          74
# 833      r2_var_145          74
# 972      r2_var_177          74
# 617      exp_var_95          74
# 876      r1_var_155          74
# 93           var_93          74
# 671    tanh_var_107          74
# 172         var_172          74
# 554       r2_var_81          74
# 807      r2_var_139          73
# 603      exp_var_92          73
# 318      exp_var_26          73
# 582     tanh_var_87          73
# 294       r1_var_21          73
# 684     exp_var_110          73
# 70           var_70          72
# 683      r2_var_110          72
# 2             var_2          72
# 87           var_87          72
# 165         var_165          72
# 956     exp_var_173          72
# 164         var_164          72
# 768      r2_var_130          72
# 52           var_52          71
# 982     exp_var_179          71
# 906      r1_var_162          71
# 512       r2_var_71          71
# 145         var_145          71
# 832      r1_var_145          71
# 783     exp_var_133          71
# 173         var_173          71
# 1066     r2_var_199          71
# 1013     r1_var_187          71
# 673      r2_var_108          70
# 156         var_156          70
# 592       r1_var_90          70
# 721     exp_var_119          70
# 549       r1_var_80          70
# 719      r1_var_119          70
# 45           var_45          69
# 881      r2_var_156          69
# 959      r2_var_174          69
# 1055     r1_var_197          69
# 150         var_150          69
# 282       r1_var_18          69
# 261      exp_var_13          69
# 913     exp_var_163          68
# 149         var_149          68
# 317       r2_var_26          68
# 933      r1_var_168          68
# 49           var_49          67
# 777      r2_var_132          67
# 424       r1_var_51          67
# 1002     r2_var_184          67
# 873      r2_var_154          67
# 954      r1_var_173          67
# 560      exp_var_82          67
# 800     exp_var_137          67
# 950      r1_var_172          67
# 260       r2_var_13          67
# 738     exp_var_123          67
# 1067    exp_var_199          67
# 581      exp_var_87          67
# 343       r2_var_32          67
# 670     exp_var_107          66
# 346       r1_var_33          66
# 357       r2_var_35          66
# 13           var_13          66
# 51           var_51          66
# 985      r2_var_180          66
# 718    tanh_var_118          66
# 624       r2_var_97          66
# 155         var_155          66
# 553       r1_var_81          66
# 180         var_180          66
# 188         var_188          66
# 917     exp_var_164          66
# 200        r1_var_0          66
# 840   log10_var_146          66
# 939     exp_var_169          66
# 395       r2_var_44          66
# 256      exp_var_12          65
# 1011    exp_var_186          65
# 573     tanh_var_85          65
# 284      exp_var_18          65
# 532       r2_var_76          65
# 699      r1_var_114          65
# 720      r2_var_119          65
# 28           var_28          64
# 733      r2_var_122          64
# 509      exp_var_70          64
# 66           var_66          64
# 104         var_104          64
# 18           var_18          64
# 44           var_44          64
# 32           var_32          64
# 701     exp_var_114          64
# 141         var_141          63
# 139         var_139          63
# 1             var_1          63
# 377       r2_var_40          63
# 527       r1_var_75          63
# 704      r2_var_115          63
# 353      exp_var_34          63
# 338       r2_var_31          63
# 31           var_31          63
# 361       r2_var_36          63
# 799      r2_var_137          63
# 907      r2_var_162          63
# 798      r1_var_137          63
# 507       r1_var_70          63
# 776      r1_var_132          63
# 428       r1_var_52          63
# 20           var_20          63
# 653      r1_var_104          62
# 290       r1_var_20          62
# 809    tanh_var_139          62
# 251       r2_var_11          62
# 613     tanh_var_94          62
# 920      r2_var_165          62
# 162         var_162          62
# 594      exp_var_90          62
# 847     exp_var_148          62
# 131         var_131          62
# 1060     r1_var_198          62
# 177         var_177          62
# 685    tanh_var_110          61
# 674     exp_var_108          61
# 759      r2_var_128          61
# 25           var_25          61
# 924      r1_var_166          61
# 814      r1_var_141          60
# 654      r2_var_104          60
# 457      exp_var_58          60
# 207       exp_var_1          60
# 1038     r1_var_193          60
# 390       r2_var_43          60
# 489       r1_var_66          60
# 1061     r2_var_198          60
# 106         var_106          59
# 943      r2_var_170          59
# 844    tanh_var_147          59
# 1036    exp_var_192          59
# 952     exp_var_172          59
# 163         var_163          59
# 616       r2_var_95          59
# 1035     r2_var_192          59
# 575       r1_var_86          59
# 92           var_92          59
# 397     tanh_var_44          59
# 827      r1_var_144          59
# 669      r2_var_107          59
# 792     exp_var_135          59
# 496      exp_var_67          58
# 416       r2_var_49          58
# 0             var_0          58
# 337       r1_var_31          58
# 986     exp_var_180          58
# 677      r1_var_109          58
# 199         var_199          58
# 191         var_191          58
# 736      r1_var_123          58
# 83           var_83          58
# 68           var_68          58
# 854      r1_var_150          58
# 692      r2_var_112          58
# 1017     r1_var_188          58
# 1065     r1_var_199          57
# 94           var_94          57
# 772      r1_var_131          57
# 843     exp_var_147          57
# 1048     r2_var_195          57
# 508       r2_var_70          57
# 981      r2_var_179          57
# 48           var_48          56
# 434      exp_var_53          56
# 396      exp_var_44          56
# 196         var_196          56
# 842      r2_var_147          56
# 841      r1_var_147          56
# 853    tanh_var_149          56
# 550       r2_var_80          56
# 703      r1_var_115          56
# 1045   tanh_var_194          56
# 413      exp_var_48          56
# 930      r2_var_167          56
# 389       r1_var_43          56
# 119         var_119          55
# 715      r1_var_118          55
# 686      r1_var_111          55
# 926     exp_var_166          55
# 195         var_195          55
# 224        r2_var_5          54
# 716      r2_var_118          54
# 850      r1_var_149          54
# 916      r2_var_164          54
# 90           var_90          54
# 105         var_105          54
# 426      exp_var_51          53
# 181         var_181          53
# 455       r1_var_58          53
# 430      exp_var_52          53
# 875    tanh_var_154          53
# 1051     r1_var_196          53
# 344      exp_var_32          53
# 707      r1_var_116          53
# 668      r1_var_107          53
# 589       r2_var_89          53
# 787      r2_var_134          53
# 894      r2_var_159          52
# 729     exp_var_121          52
# 815      r2_var_141          52
# 175         var_175          52
# 828      r2_var_144          52
# 851      r2_var_149          52
# 593       r2_var_90          52
# 203      tanh_var_0          52
# 64           var_64          51
# 57           var_57          51
# 810      r1_var_140          51
# 157         var_157          51
# 790      r1_var_135          51
# 801    tanh_var_137          51
# 194         var_194          51
# 472       r1_var_62          51
# 937      r1_var_169          50
# 769     exp_var_130          50
# 82           var_82          50
# 791      r2_var_135          50
# 576       r2_var_86          50
# 1042     r1_var_194          50
# 309      exp_var_24          50
# 212      tanh_var_2          50
# 61           var_61          50
# 138         var_138          50
# 225       exp_var_5          50
# 1037   tanh_var_192          50
# 226      tanh_var_5          50
# 552     tanh_var_80          50
# 693     exp_var_112          50
# 441       r1_var_55          50
# 700      r2_var_114          49
# 678      r2_var_109          49
# 310     tanh_var_24          49
# 570       r1_var_85          49
# 529      exp_var_75          49
# 75           var_75          49
# 976      r1_var_178          49
# 1052     r2_var_196          49
# 296      exp_var_21          49
# 565     tanh_var_83          49
# 963      r2_var_175          49
# 137         var_137          49
# 229       exp_var_6          49
# 618     tanh_var_95          48
# 838     exp_var_146          48
# 1062    exp_var_198          48
# 859      r1_var_151          48
# 880      r1_var_156          48
# 860      r2_var_151          48
# 534     tanh_var_76          48
# 399       r2_var_45          48
# 308       r2_var_24          48
# 252      exp_var_11          48
# 319     tanh_var_26          48
# 214        r1_var_3          48
# 400      exp_var_45          48
# 56           var_56          48
# 154         var_154          48
# 86           var_86          48
# 325       r2_var_28          47
# 503       r1_var_69          47
# 706    tanh_var_115          47
# 786      r1_var_134          47
# 579       r1_var_87          47
# 239       exp_var_8          47
# 97           var_97          47
# 412       r2_var_48          47
# 1032    exp_var_191          47
# 398       r1_var_45          46
# 855      r2_var_150          46
# 211       exp_var_2          46
# 439      exp_var_54          46
# 802      r1_var_138          46
# 186         var_186          46
# 910   log10_var_162          46
# 514     tanh_var_71          46
# 563       r2_var_83          46
# 135         var_135          46
# 425       r2_var_51          46
# 63           var_63          46
# 946      r1_var_171          46
# 818      r1_var_142          46
# 292      exp_var_20          45
# 667   log10_var_106          45
# 312       r2_var_25          45
# 364       r1_var_37          45
# 50           var_50          45
# 559       r2_var_82          45
# 418     tanh_var_49          45
# 363     tanh_var_36          44
# 524       r2_var_74          44
# 128         var_128          44
# 687      r2_var_111          44
# 326      exp_var_28          44
# 757    tanh_var_127          44
# 596       r1_var_91          43
# 391      exp_var_43          43
# 525      exp_var_74          43
# 945    tanh_var_170          43
# 21           var_21          43
# 1040    exp_var_193          43
# 55           var_55          43
# 1010     r2_var_186          43
# 237        r1_var_8          43
# 861     exp_var_151          42

# %% [markdown]
# #### Feature scaling

# %%
sc = StandardScaler()
scaled_X_train=sc.fit_transform(X_train)
scaled_X_valid=sc.fit_transform(X_valid)

train_data = lgb.Dataset(scaled_X_train, label=y_train)
validation_data = lgb.Dataset(scaled_X_valid, label=y_valid)

# %%
num_round = 15000
scaled_lgb_clf = lgb.train(param, train_data, num_round, valid_sets=[validation_data],verbose_eval=1000, early_stopping_rounds = 250)
# Out:
# Training until validation scores don't improve for 250 rounds.
# [1000]	valid_0's auc: 0.848944
# [2000]	valid_0's auc: 0.871042
# [3000]	valid_0's auc: 0.880982
# [4000]	valid_0's auc: 0.885394
# [5000]	valid_0's auc: 0.888294
# [6000]	valid_0's auc: 0.889617
# Early stopping, best iteration is:
# [6194]	valid_0's auc: 0.889858

# %% [markdown]
# Did not work well with the exp, tanh, and log10. Only 0.8898.
# It was better with the cubic before. Standard scaler may conflict with feature engineering.

# %%
scaled_lgb_clf.save_model('scaled_lgb_clf.txt')

# %%
scaled_importance_df = pd.DataFrame()
scaled_importance_df["Feature"] = features
scaled_importance_df["importance"] = scaled_lgb_clf.feature_importance()
scaled_importance_df.sort_values(by=['importance'], ascending=False)[:20]
# Out:
#          Feature  importance
# 768    r1_var_94         154
# 210     r1_var_1         154
# 282    r1_var_13         140
# 756    r1_var_92         139
# 799    r2_var_99         129
# 336    r1_var_22         128
# 139      var_139         125
# 234     r1_var_5         123
# 684    r1_var_80         119
# 522    r1_var_53         117
# 312    r1_var_18         117
# 1224  r1_var_170         116
# 1344  r1_var_190         115
# 1188  r1_var_164         115
# 658     c_var_76         115
# 934    c_var_122         115
# 1284  r1_var_180         115
# 1086  r1_var_147         114
# 751    r2_var_91         113
# 661    r2_var_76         110

# %% [markdown]
# ### xgboost

# %%
import xgboost as xgb

# %%
param = {
        'eta': 0.1,
        'max_depth': 15,
        'gamma': 100,
        'objective':'binary:logistic',    
        'eval_metric':'auc',
        'seed':42
        }

# %%
xgb_param = {
    'min_child_weight': 10.0,
    'objective': 'binary:logistic',
    'max_depth': 7,
    'max_delta_step': 1.8,
    'colsample_bytree': 0.4,
    'subsample': 0.8,
    'eta': 0.025,
    'gamma': 0.65,
    'eval_metric':'auc'
        }

# %%
X.shape,y.shape
# Out:
# ((200000, 200), (200000,))

# %%
oof = np.zeros(len(X))
#predictions = np.zeros(len(X_test))
#feature_importance_df = pd.DataFrame()

for i, (train_idx, valid_idx) in enumerate(splits):  
    print(f'Fold {i + 1}')
    x_train = np.array(X)
    y_train = np.array(y)
    trn_data = xgb.DMatrix(x_train[train_idx.astype(int)], label=y_train[train_idx.astype(int)])
    val_data = xgb.DMatrix(x_train[valid_idx.astype(int)], label=y_train[valid_idx.astype(int)])
    watchlist = [(trn_data, 'train'), (val_data, 'valid')]
                 
    #num_round = 15000
    clf=xgb.train(param, trn_data, 700, evals=watchlist, early_stopping_rounds=250, verbose_eval=500)
    
    oof[valid_idx] = clf.predict(x_train[valid_idx], ntree_limit=clf.best_ntree_limit)
    
    #fold_importance_df = pd.DataFrame()
    #fold_importance_df["feature"] = features
    #fold_importance_df["importance"] = clf.feature_importance()
    #fold_importance_df["fold"] = i + 1
    #feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
    
    #predictions += clf.predict(X_test, num_iteration=clf.best_iteration) / 5

print("CV score: {:<8.5f}".format(roc_auc_score(y, oof)))
# Out:
# Fold 1
# [22:18:28] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 142 extra nodes, 0 pruned nodes, max_depth=7
# [0]	train-auc:0.636529	valid-auc:0.617924
# Multiple eval metrics have been passed: 'valid-auc' will be used for early stopping.
#
# Will train until valid-auc hasn't improved in 250 rounds.
# [22:18:29] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 142 extra nodes, 0 pruned nodes, max_depth=7
# [22:18:30] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 138 extra nodes, 0 pruned nodes, max_depth=7
# [22:18:31] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 136 extra nodes, 0 pruned nodes, max_depth=7
# [22:18:32] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 158 extra nodes, 0 pruned nodes, max_depth=7
# [22:18:33] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 156 extra nodes, 0 pruned nodes, max_depth=7
# [22:18:34] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 164 extra nodes, 0 pruned nodes, max_depth=7
# [22:18:35] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 148 extra nodes, 0 pruned nodes, max_depth=7
# [22:18:36] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 162 extra nodes, 0 pruned nodes, max_depth=7
# [22:18:37] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 152 extra nodes, 0 pruned nodes, max_depth=7
# [22:18:38] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 156 extra nodes, 0 pruned nodes, max_depth=7
# [22:18:39] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 170 extra nodes, 0 pruned nodes, max_depth=7
# [22:18:40] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 148 extra nodes, 2 pruned nodes, max_depth=7
# [22:18:41] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 148 extra nodes, 0 pruned nodes, max_depth=7
# [22:18:42] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 156 extra nodes, 0 pruned nodes, max_depth=7
# [22:18:43] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 170 extra nodes, 0 pruned nodes, max_depth=7
# [22:18:44] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 150 extra nodes, 0 pruned nodes, max_depth=7
# [22:18:45] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 156 extra nodes, 0 pruned nodes, max_depth=7
# [22:18:46] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 152 extra nodes, 0 pruned nodes, max_depth=7
# [22:18:47] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 126 extra nodes, 0 pruned nodes, max_depth=7
# [22:18:47] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 168 extra nodes, 0 pruned nodes, max_depth=7
# [22:18:48] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 172 extra nodes, 0 pruned nodes, max_depth=7
# [22:18:49] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 118 extra nodes, 0 pruned nodes, max_depth=7
# [22:18:50] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 160 extra nodes, 0 pruned nodes, max_depth=7
# [22:18:51] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 184 extra nodes, 0 pruned nodes, max_depth=7
# [22:18:52] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 156 extra nodes, 0 pruned nodes, max_depth=7
# [22:18:53] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 122 extra nodes, 0 pruned nodes, max_depth=7
# [22:18:54] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 156 extra nodes, 0 pruned nodes, max_depth=7
# [22:18:55] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 150 extra nodes, 0 pruned nodes, max_depth=7
# [22:18:56] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 144 extra nodes, 0 pruned nodes, max_depth=7
# [22:18:57] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 170 extra nodes, 2 pruned nodes, max_depth=7
# [22:18:58] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 152 extra nodes, 0 pruned nodes, max_depth=7
# [22:18:59] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 156 extra nodes, 0 pruned nodes, max_depth=7
# [22:19:00] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 152 extra nodes, 0 pruned nodes, max_depth=7
# [22:19:01] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 166 extra nodes, 0 pruned nodes, max_depth=7
# [22:19:02] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 124 extra nodes, 0 pruned nodes, max_depth=7
# [22:19:03] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 150 extra nodes, 0 pruned nodes, max_depth=7
# [22:19:04] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 136 extra nodes, 0 pruned nodes, max_depth=7
# [22:19:05] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 150 extra nodes, 0 pruned nodes, max_depth=7
# [22:19:06] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 150 extra nodes, 0 pruned nodes, max_depth=7
# [22:19:07] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 172 extra nodes, 0 pruned nodes, max_depth=7
# [22:19:08] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 158 extra nodes, 0 pruned nodes, max_depth=7
# [22:19:09] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 150 extra nodes, 0 pruned nodes, max_depth=7
# [22:19:10] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 162 extra nodes, 0 pruned nodes, max_depth=7
# [22:19:11] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 166 extra nodes, 0 pruned nodes, max_depth=7
# [22:19:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 126 extra nodes, 0 pruned nodes, max_depth=7
# [22:19:13] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 158 extra nodes, 0 pruned nodes, max_depth=7
# [22:19:14] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 164 extra nodes, 0 pruned nodes, max_depth=7
# [22:19:15] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 164 extra nodes, 0 pruned nodes, max_depth=7
# [22:19:16] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 172 extra nodes, 0 pruned nodes, max_depth=7
# [22:19:16] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 136 extra nodes, 0 pruned nodes, max_depth=7
# [22:19:17] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 156 extra nodes, 0 pruned nodes, max_depth=7
# [22:19:18] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 138 extra nodes, 0 pruned nodes, max_depth=7
# [22:19:19] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 158 extra nodes, 0 pruned nodes, max_depth=7
# [22:19:20] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 168 extra nodes, 0 pruned nodes, max_depth=7
# [22:19:21] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 164 extra nodes, 0 pruned nodes, max_depth=7
# [22:19:22] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 132 extra nodes, 0 pruned nodes, max_depth=7
# [22:19:23] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 180 extra nodes, 0 pruned nodes, max_depth=7
# [22:19:24] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 170 extra nodes, 0 pruned nodes, max_depth=7
# [22:19:25] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 168 extra nodes, 0 pruned nodes, max_depth=7
# [22:19:26] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 144 extra nodes, 0 pruned nodes, max_depth=7
# [22:19:27] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 128 extra nodes, 0 pruned nodes, max_depth=7
# [22:19:28] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 154 extra nodes, 0 pruned nodes, max_depth=7
# [22:19:30] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 148 extra nodes, 0 pruned nodes, max_depth=7
# [22:19:31] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 164 extra nodes, 0 pruned nodes, max_depth=7
# [22:19:32] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 190 extra nodes, 0 pruned nodes, max_depth=7
# [22:19:33] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 156 extra nodes, 0 pruned nodes, max_depth=7
# [22:19:34] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 152 extra nodes, 0 pruned nodes, max_depth=7
# [22:19:35] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 140 extra nodes, 0 pruned nodes, max_depth=7
# [22:19:36] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 146 extra nodes, 0 pruned nodes, max_depth=7
# [22:19:37] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 142 extra nodes, 0 pruned nodes, max_depth=7
# [22:19:38] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 154 extra nodes, 0 pruned nodes, max_depth=7
# [22:19:39] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 164 extra nodes, 0 pruned nodes, max_depth=7
# [22:19:40] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 166 extra nodes, 0 pruned nodes, max_depth=7
# [22:19:41] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 138 extra nodes, 0 pruned nodes, max_depth=7
# [22:19:42] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 136 extra nodes, 0 pruned nodes, max_depth=7
# [22:19:43] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 166 extra nodes, 0 pruned nodes, max_depth=7
# [22:19:44] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 134 extra nodes, 0 pruned nodes, max_depth=7
# [22:19:45] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 152 extra nodes, 0 pruned nodes, max_depth=7
# [22:19:46] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 136 extra nodes, 0 pruned nodes, max_depth=7
# [22:19:47] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 136 extra nodes, 0 pruned nodes, max_depth=7
# [22:19:48] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 170 extra nodes, 0 pruned nodes, max_depth=7
# [22:19:49] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 142 extra nodes, 0 pruned nodes, max_depth=7
# [22:19:50] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 156 extra nodes, 0 pruned nodes, max_depth=7
# [22:19:51] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 162 extra nodes, 0 pruned nodes, max_depth=7
# [22:19:52] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 154 extra nodes, 0 pruned nodes, max_depth=7
# [22:19:53] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 152 extra nodes, 0 pruned nodes, max_depth=7
# [22:19:54] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 164 extra nodes, 0 pruned nodes, max_depth=7
# [22:19:55] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 162 extra nodes, 2 pruned nodes, max_depth=7
# [22:19:56] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 150 extra nodes, 0 pruned nodes, max_depth=7
# [22:19:57] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 148 extra nodes, 0 pruned nodes, max_depth=7
# [22:19:58] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 168 extra nodes, 0 pruned nodes, max_depth=7
# [22:19:59] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 166 extra nodes, 0 pruned nodes, max_depth=7
# [22:20:00] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 170 extra nodes, 0 pruned nodes, max_depth=7
# [22:20:01] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 140 extra nodes, 0 pruned nodes, max_depth=7
# [22:20:02] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 150 extra nodes, 0 pruned nodes, max_depth=7
# [22:20:03] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 154 extra nodes, 0 pruned nodes, max_depth=7
# [22:20:04] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 148 extra nodes, 0 pruned nodes, max_depth=7
# [22:20:05] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 172 extra nodes, 0 pruned nodes, max_depth=7
# [22:20:06] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 168 extra nodes, 0 pruned nodes, max_depth=7
# [22:20:07] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 136 extra nodes, 0 pruned nodes, max_depth=7
# [22:20:08] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 174 extra nodes, 2 pruned nodes, max_depth=7
# [22:20:09] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 148 extra nodes, 2 pruned nodes, max_depth=7
# [22:20:10] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 172 extra nodes, 0 pruned nodes, max_depth=7
# [22:20:11] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 160 extra nodes, 0 pruned nodes, max_depth=7
# [22:20:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 140 extra nodes, 0 pruned nodes, max_depth=7
# [22:20:13] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 180 extra nodes, 0 pruned nodes, max_depth=7
# [22:20:14] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 164 extra nodes, 0 pruned nodes, max_depth=7
# [22:20:15] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 154 extra nodes, 0 pruned nodes, max_depth=7
# [22:20:16] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 170 extra nodes, 2 pruned nodes, max_depth=7
# [22:20:17] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 142 extra nodes, 0 pruned nodes, max_depth=7
# [22:20:18] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 146 extra nodes, 0 pruned nodes, max_depth=7
# [22:20:19] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 156 extra nodes, 0 pruned nodes, max_depth=7
# [22:20:20] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 162 extra nodes, 0 pruned nodes, max_depth=7
# [22:20:21] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 140 extra nodes, 0 pruned nodes, max_depth=7
# [22:20:22] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 0 pruned nodes, max_depth=7
# [22:20:23] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 152 extra nodes, 0 pruned nodes, max_depth=7
# [22:20:24] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 170 extra nodes, 0 pruned nodes, max_depth=7
# [22:20:25] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 128 extra nodes, 0 pruned nodes, max_depth=7
# [22:20:26] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 140 extra nodes, 0 pruned nodes, max_depth=7
# [22:20:27] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 178 extra nodes, 0 pruned nodes, max_depth=7
# [22:20:28] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 162 extra nodes, 0 pruned nodes, max_depth=7
# [22:20:29] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 160 extra nodes, 0 pruned nodes, max_depth=7
# [22:20:30] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 160 extra nodes, 0 pruned nodes, max_depth=7
# [22:20:31] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 196 extra nodes, 0 pruned nodes, max_depth=7
# [22:20:32] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 138 extra nodes, 2 pruned nodes, max_depth=7
# [22:20:33] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 182 extra nodes, 2 pruned nodes, max_depth=7
# [22:20:34] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 194 extra nodes, 0 pruned nodes, max_depth=7
# [22:20:35] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 140 extra nodes, 0 pruned nodes, max_depth=7
# [22:20:36] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 160 extra nodes, 2 pruned nodes, max_depth=7
# [22:20:37] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 132 extra nodes, 0 pruned nodes, max_depth=7
# [22:20:38] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 154 extra nodes, 0 pruned nodes, max_depth=7
# [22:20:39] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 124 extra nodes, 0 pruned nodes, max_depth=7
# [22:20:40] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 172 extra nodes, 0 pruned nodes, max_depth=7
# [22:20:41] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 164 extra nodes, 0 pruned nodes, max_depth=7
# [22:20:42] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 148 extra nodes, 0 pruned nodes, max_depth=7
# [22:20:43] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 142 extra nodes, 0 pruned nodes, max_depth=7
# [22:20:44] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 144 extra nodes, 0 pruned nodes, max_depth=7
# [22:20:45] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 122 extra nodes, 0 pruned nodes, max_depth=7
# [22:20:46] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 120 extra nodes, 0 pruned nodes, max_depth=7
# [22:20:47] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 160 extra nodes, 0 pruned nodes, max_depth=7
# [22:20:48] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 140 extra nodes, 0 pruned nodes, max_depth=7
# [22:20:49] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 176 extra nodes, 0 pruned nodes, max_depth=7
# [22:20:50] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 158 extra nodes, 0 pruned nodes, max_depth=7
# [22:20:51] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 156 extra nodes, 0 pruned nodes, max_depth=7
# [22:20:52] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 166 extra nodes, 0 pruned nodes, max_depth=7
# [22:20:53] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 138 extra nodes, 2 pruned nodes, max_depth=7
# [22:20:55] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 160 extra nodes, 0 pruned nodes, max_depth=7
# [22:20:56] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 172 extra nodes, 0 pruned nodes, max_depth=7
# [22:20:57] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 138 extra nodes, 0 pruned nodes, max_depth=7
# [22:20:58] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 166 extra nodes, 2 pruned nodes, max_depth=7
# [22:20:59] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 174 extra nodes, 0 pruned nodes, max_depth=7
# [22:21:00] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 158 extra nodes, 0 pruned nodes, max_depth=7
# [22:21:01] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 138 extra nodes, 0 pruned nodes, max_depth=7
# [22:21:02] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 126 extra nodes, 0 pruned nodes, max_depth=7
# [22:21:03] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 120 extra nodes, 0 pruned nodes, max_depth=7
# [22:21:04] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 140 extra nodes, 0 pruned nodes, max_depth=7
# [22:21:05] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 156 extra nodes, 0 pruned nodes, max_depth=7
# [22:21:06] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 136 extra nodes, 0 pruned nodes, max_depth=7
# [22:21:07] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 144 extra nodes, 0 pruned nodes, max_depth=7
# [22:21:09] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 150 extra nodes, 0 pruned nodes, max_depth=7
# [22:21:10] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 150 extra nodes, 0 pruned nodes, max_depth=7
# [22:21:11] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 150 extra nodes, 0 pruned nodes, max_depth=7
# [22:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 184 extra nodes, 0 pruned nodes, max_depth=7
# [22:21:13] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 136 extra nodes, 0 pruned nodes, max_depth=7
# [22:21:14] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 178 extra nodes, 0 pruned nodes, max_depth=7
# [22:21:15] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 148 extra nodes, 0 pruned nodes, max_depth=7
# [22:21:16] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 166 extra nodes, 0 pruned nodes, max_depth=7
# [22:21:18] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 144 extra nodes, 0 pruned nodes, max_depth=7
# [22:21:19] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 128 extra nodes, 0 pruned nodes, max_depth=7
# [22:21:20] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 196 extra nodes, 0 pruned nodes, max_depth=7
# [22:21:21] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 138 extra nodes, 0 pruned nodes, max_depth=7
# [22:21:23] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 134 extra nodes, 0 pruned nodes, max_depth=7
# [22:21:24] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 142 extra nodes, 0 pruned nodes, max_depth=7
# [22:21:25] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 144 extra nodes, 0 pruned nodes, max_depth=7
# [22:21:26] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 188 extra nodes, 0 pruned nodes, max_depth=7
# [22:21:27] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 178 extra nodes, 0 pruned nodes, max_depth=7
# [22:21:28] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 148 extra nodes, 0 pruned nodes, max_depth=7
# [22:21:29] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 156 extra nodes, 0 pruned nodes, max_depth=7
# [22:21:30] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 158 extra nodes, 0 pruned nodes, max_depth=7
# [22:21:31] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 178 extra nodes, 0 pruned nodes, max_depth=7
# [22:21:32] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 170 extra nodes, 0 pruned nodes, max_depth=7
# [22:21:33] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 126 extra nodes, 0 pruned nodes, max_depth=7
# [22:21:34] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 154 extra nodes, 0 pruned nodes, max_depth=7
# [22:21:35] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 146 extra nodes, 0 pruned nodes, max_depth=7
# [22:21:37] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 126 extra nodes, 0 pruned nodes, max_depth=7
# [22:21:38] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 160 extra nodes, 0 pruned nodes, max_depth=7
# [22:21:39] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 116 extra nodes, 0 pruned nodes, max_depth=7
# [22:21:40] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 160 extra nodes, 0 pruned nodes, max_depth=7
# [22:21:42] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 172 extra nodes, 0 pruned nodes, max_depth=7
# [22:21:43] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 154 extra nodes, 0 pruned nodes, max_depth=7
# [22:21:44] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 112 extra nodes, 2 pruned nodes, max_depth=7
# [22:21:45] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 142 extra nodes, 0 pruned nodes, max_depth=7
# [22:21:46] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 144 extra nodes, 0 pruned nodes, max_depth=7
# [22:21:47] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 148 extra nodes, 0 pruned nodes, max_depth=7
# [22:21:49] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 140 extra nodes, 0 pruned nodes, max_depth=7
# [22:21:50] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 166 extra nodes, 2 pruned nodes, max_depth=7
# [22:21:51] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 128 extra nodes, 0 pruned nodes, max_depth=7
# [22:21:52] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 186 extra nodes, 0 pruned nodes, max_depth=7
# [22:21:53] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 138 extra nodes, 0 pruned nodes, max_depth=7
# [22:21:54] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 140 extra nodes, 0 pruned nodes, max_depth=7
# [22:21:55] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 156 extra nodes, 0 pruned nodes, max_depth=7
# [22:21:56] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 142 extra nodes, 0 pruned nodes, max_depth=7
# [22:21:57] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 146 extra nodes, 0 pruned nodes, max_depth=7
# [22:21:58] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 154 extra nodes, 2 pruned nodes, max_depth=7
# [22:21:59] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 152 extra nodes, 0 pruned nodes, max_depth=7
# [22:22:01] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 166 extra nodes, 0 pruned nodes, max_depth=7
# [22:22:02] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 150 extra nodes, 0 pruned nodes, max_depth=7
# [22:22:03] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 166 extra nodes, 0 pruned nodes, max_depth=7
# [22:22:04] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 146 extra nodes, 0 pruned nodes, max_depth=7
# [22:22:05] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 160 extra nodes, 0 pruned nodes, max_depth=7
# [22:22:06] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 162 extra nodes, 0 pruned nodes, max_depth=7
# [22:22:07] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 148 extra nodes, 0 pruned nodes, max_depth=7
# [22:22:08] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 156 extra nodes, 0 pruned nodes, max_depth=7
# [22:22:09] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 182 extra nodes, 0 pruned nodes, max_depth=7
# [22:22:10] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 148 extra nodes, 0 pruned nodes, max_depth=7
# [22:22:11] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 174 extra nodes, 0 pruned nodes, max_depth=7
# [22:22:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 166 extra nodes, 0 pruned nodes, max_depth=7
# [22:22:13] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 160 extra nodes, 0 pruned nodes, max_depth=7
# [22:22:14] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 148 extra nodes, 0 pruned nodes, max_depth=7
# [22:22:15] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 152 extra nodes, 0 pruned nodes, max_depth=7
# [22:22:16] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 162 extra nodes, 0 pruned nodes, max_depth=7
# [22:22:17] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 162 extra nodes, 0 pruned nodes, max_depth=7
# [22:22:18] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 176 extra nodes, 0 pruned nodes, max_depth=7
# [22:22:19] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 168 extra nodes, 0 pruned nodes, max_depth=7
# [22:22:20] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 150 extra nodes, 0 pruned nodes, max_depth=7
# [22:22:22] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 184 extra nodes, 0 pruned nodes, max_depth=7
# [22:22:23] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 140 extra nodes, 0 pruned nodes, max_depth=7
# [22:22:24] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 136 extra nodes, 0 pruned nodes, max_depth=7
# [22:22:25] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 164 extra nodes, 0 pruned nodes, max_depth=7
# [22:22:26] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 194 extra nodes, 0 pruned nodes, max_depth=7
# [22:22:27] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 164 extra nodes, 0 pruned nodes, max_depth=7
# [22:22:28] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 158 extra nodes, 0 pruned nodes, max_depth=7
# [22:22:29] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 144 extra nodes, 0 pruned nodes, max_depth=7
# [22:22:30] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 140 extra nodes, 0 pruned nodes, max_depth=7
# [22:22:31] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 122 extra nodes, 0 pruned nodes, max_depth=7
# [22:22:32] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 170 extra nodes, 0 pruned nodes, max_depth=7
# [22:22:34] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 142 extra nodes, 0 pruned nodes, max_depth=7
# [22:22:35] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 168 extra nodes, 0 pruned nodes, max_depth=7
# [22:22:36] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 146 extra nodes, 0 pruned nodes, max_depth=7
# [22:22:37] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 166 extra nodes, 0 pruned nodes, max_depth=7
# [22:22:38] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 144 extra nodes, 0 pruned nodes, max_depth=7
# [22:22:39] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 126 extra nodes, 0 pruned nodes, max_depth=7
# [22:22:40] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 176 extra nodes, 0 pruned nodes, max_depth=7
# [22:22:41] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 140 extra nodes, 0 pruned nodes, max_depth=7
# [22:22:43] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 186 extra nodes, 0 pruned nodes, max_depth=7
# [22:22:44] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 154 extra nodes, 0 pruned nodes, max_depth=7
# [22:22:45] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 142 extra nodes, 0 pruned nodes, max_depth=7
# [22:22:46] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 176 extra nodes, 0 pruned nodes, max_depth=7
# [22:22:47] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 180 extra nodes, 0 pruned nodes, max_depth=7
# [22:22:48] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 134 extra nodes, 0 pruned nodes, max_depth=7
# [22:22:49] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 140 extra nodes, 0 pruned nodes, max_depth=7
# [22:22:50] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 178 extra nodes, 0 pruned nodes, max_depth=7
# [22:22:52] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 148 extra nodes, 0 pruned nodes, max_depth=7
# [22:22:53] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 168 extra nodes, 0 pruned nodes, max_depth=7
# [22:22:54] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 140 extra nodes, 0 pruned nodes, max_depth=7
# [22:22:55] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 146 extra nodes, 0 pruned nodes, max_depth=7
# [22:22:56] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 128 extra nodes, 0 pruned nodes, max_depth=7
# [22:22:57] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 168 extra nodes, 0 pruned nodes, max_depth=7
# [22:22:58] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 146 extra nodes, 0 pruned nodes, max_depth=7
# [22:22:59] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 166 extra nodes, 0 pruned nodes, max_depth=7
# [22:23:00] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 160 extra nodes, 0 pruned nodes, max_depth=7
# [22:23:01] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 140 extra nodes, 0 pruned nodes, max_depth=7
# [22:23:02] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 154 extra nodes, 0 pruned nodes, max_depth=7
# [22:23:03] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 150 extra nodes, 0 pruned nodes, max_depth=7
# [22:23:04] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 160 extra nodes, 2 pruned nodes, max_depth=7
# [22:23:05] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 160 extra nodes, 0 pruned nodes, max_depth=7
# [22:23:06] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 170 extra nodes, 0 pruned nodes, max_depth=7
# [22:23:07] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 162 extra nodes, 0 pruned nodes, max_depth=7
# [22:23:09] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 164 extra nodes, 0 pruned nodes, max_depth=7
# [22:23:10] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 130 extra nodes, 0 pruned nodes, max_depth=7
# [22:23:11] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 172 extra nodes, 0 pruned nodes, max_depth=7
# [22:23:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 158 extra nodes, 0 pruned nodes, max_depth=7
# [22:23:13] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 156 extra nodes, 0 pruned nodes, max_depth=7
# [22:23:14] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 126 extra nodes, 0 pruned nodes, max_depth=7
# [22:23:15] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 158 extra nodes, 0 pruned nodes, max_depth=7
# [22:23:16] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 162 extra nodes, 0 pruned nodes, max_depth=7
# [22:23:17] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 168 extra nodes, 0 pruned nodes, max_depth=7
# [22:23:19] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 162 extra nodes, 0 pruned nodes, max_depth=7
# [22:23:20] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 184 extra nodes, 0 pruned nodes, max_depth=7
# [22:23:21] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 138 extra nodes, 0 pruned nodes, max_depth=7
# [22:23:22] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 108 extra nodes, 0 pruned nodes, max_depth=7
# [22:23:23] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 192 extra nodes, 0 pruned nodes, max_depth=7
# [22:23:24] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 188 extra nodes, 0 pruned nodes, max_depth=7
# [22:23:25] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 124 extra nodes, 0 pruned nodes, max_depth=7
# [22:23:26] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 158 extra nodes, 0 pruned nodes, max_depth=7
# [22:23:27] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 158 extra nodes, 0 pruned nodes, max_depth=7
# [22:23:28] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 178 extra nodes, 0 pruned nodes, max_depth=7
# [22:23:29] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 142 extra nodes, 0 pruned nodes, max_depth=7
# [22:23:31] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 150 extra nodes, 0 pruned nodes, max_depth=7
# [22:23:32] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 130 extra nodes, 0 pruned nodes, max_depth=7
# [22:23:33] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 144 extra nodes, 0 pruned nodes, max_depth=7
# [22:23:34] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 166 extra nodes, 0 pruned nodes, max_depth=7
# [22:23:35] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 152 extra nodes, 0 pruned nodes, max_depth=7
# [22:23:36] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 180 extra nodes, 0 pruned nodes, max_depth=7
# [22:23:37] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 144 extra nodes, 0 pruned nodes, max_depth=7
# [22:23:38] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 132 extra nodes, 0 pruned nodes, max_depth=7
# [22:23:39] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 160 extra nodes, 0 pruned nodes, max_depth=7
# [22:23:40] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 122 extra nodes, 0 pruned nodes, max_depth=7
# [22:23:42] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 164 extra nodes, 0 pruned nodes, max_depth=7
# [22:23:43] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 164 extra nodes, 0 pruned nodes, max_depth=7
# [22:23:44] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 134 extra nodes, 0 pruned nodes, max_depth=7
# [22:23:45] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 204 extra nodes, 0 pruned nodes, max_depth=7
# [22:23:46] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 142 extra nodes, 0 pruned nodes, max_depth=7
# [22:23:47] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 166 extra nodes, 0 pruned nodes, max_depth=7
# [22:23:48] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 172 extra nodes, 0 pruned nodes, max_depth=7
# [22:23:49] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 130 extra nodes, 0 pruned nodes, max_depth=7
# [22:23:50] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 156 extra nodes, 0 pruned nodes, max_depth=7
# [22:23:51] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 168 extra nodes, 0 pruned nodes, max_depth=7
# [22:23:52] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 168 extra nodes, 0 pruned nodes, max_depth=7
# [22:23:53] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 182 extra nodes, 0 pruned nodes, max_depth=7
# [22:23:54] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 158 extra nodes, 0 pruned nodes, max_depth=7
# [22:23:55] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 128 extra nodes, 0 pruned nodes, max_depth=7
# [22:23:56] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 132 extra nodes, 0 pruned nodes, max_depth=7
# ...
# [22:29:10] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 174 extra nodes, 0 pruned nodes, max_depth=7
# [22:29:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 166 extra nodes, 0 pruned nodes, max_depth=7
# [22:29:13] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 156 extra nodes, 2 pruned nodes, max_depth=7
# [22:29:14] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 160 extra nodes, 0 pruned nodes, max_depth=7
# [22:29:15] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 110 extra nodes, 0 pruned nodes, max_depth=7
# [22:29:16] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 142 extra nodes, 0 pruned nodes, max_depth=7
# [22:29:17] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 142 extra nodes, 0 pruned nodes, max_depth=7
# [22:29:18] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 120 extra nodes, 0 pruned nodes, max_depth=7
# [22:29:19] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 178 extra nodes, 0 pruned nodes, max_depth=7
# [22:29:20] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 162 extra nodes, 0 pruned nodes, max_depth=7
# [22:29:21] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 154 extra nodes, 0 pruned nodes, max_depth=7
# [22:29:22] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 164 extra nodes, 0 pruned nodes, max_depth=7
# [22:29:23] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 132 extra nodes, 2 pruned nodes, max_depth=7
# [22:29:24] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 160 extra nodes, 0 pruned nodes, max_depth=7
# [22:29:25] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 134 extra nodes, 0 pruned nodes, max_depth=7
# [22:29:26] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 132 extra nodes, 0 pruned nodes, max_depth=7
# [22:29:27] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 170 extra nodes, 0 pruned nodes, max_depth=7
# [22:29:28] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 146 extra nodes, 0 pruned nodes, max_depth=7
# [22:29:29] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 132 extra nodes, 0 pruned nodes, max_depth=7
# [22:29:30] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 150 extra nodes, 0 pruned nodes, max_depth=7
# [22:29:31] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 132 extra nodes, 0 pruned nodes, max_depth=7
# [22:29:32] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 148 extra nodes, 0 pruned nodes, max_depth=7
# [22:29:33] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 190 extra nodes, 0 pruned nodes, max_depth=7
# [22:29:34] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 160 extra nodes, 0 pruned nodes, max_depth=7
# [22:29:35] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 130 extra nodes, 0 pruned nodes, max_depth=7
# [22:29:36] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 158 extra nodes, 0 pruned nodes, max_depth=7
# [22:29:37] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 152 extra nodes, 0 pruned nodes, max_depth=7
# [22:29:38] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 162 extra nodes, 0 pruned nodes, max_depth=7
# [22:29:39] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 122 extra nodes, 0 pruned nodes, max_depth=7
# [22:29:40] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 162 extra nodes, 0 pruned nodes, max_depth=7
# [22:29:41] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 138 extra nodes, 0 pruned nodes, max_depth=7
# [22:29:42] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 166 extra nodes, 0 pruned nodes, max_depth=7
# [22:29:43] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 130 extra nodes, 0 pruned nodes, max_depth=7
# [22:29:44] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 126 extra nodes, 0 pruned nodes, max_depth=7
# [22:29:45] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 178 extra nodes, 0 pruned nodes, max_depth=7
# [22:29:46] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 116 extra nodes, 0 pruned nodes, max_depth=7
# [22:29:47] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 132 extra nodes, 0 pruned nodes, max_depth=7
# [22:29:48] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 134 extra nodes, 0 pruned nodes, max_depth=7
# [22:29:49] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 138 extra nodes, 0 pruned nodes, max_depth=7
# [22:29:50] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 134 extra nodes, 0 pruned nodes, max_depth=7
# [22:29:51] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 124 extra nodes, 0 pruned nodes, max_depth=7
# [22:29:52] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 168 extra nodes, 0 pruned nodes, max_depth=7
# [22:29:53] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 158 extra nodes, 0 pruned nodes, max_depth=7
# [22:29:54] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 138 extra nodes, 0 pruned nodes, max_depth=7
# [22:29:55] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 122 extra nodes, 0 pruned nodes, max_depth=7
# [22:29:57] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 172 extra nodes, 0 pruned nodes, max_depth=7
# [22:29:58] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 156 extra nodes, 0 pruned nodes, max_depth=7
# [22:29:59] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 152 extra nodes, 0 pruned nodes, max_depth=7
# [22:30:00] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 108 extra nodes, 0 pruned nodes, max_depth=7
# [22:30:02] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 138 extra nodes, 0 pruned nodes, max_depth=7
# [22:30:03] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 154 extra nodes, 0 pruned nodes, max_depth=7
# [22:30:04] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 130 extra nodes, 0 pruned nodes, max_depth=7
# [22:30:06] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 138 extra nodes, 2 pruned nodes, max_depth=7
# [22:30:07] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 160 extra nodes, 0 pruned nodes, max_depth=7
# [22:30:08] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 152 extra nodes, 0 pruned nodes, max_depth=7
# [22:30:09] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 156 extra nodes, 0 pruned nodes, max_depth=7
# [22:30:10] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 130 extra nodes, 0 pruned nodes, max_depth=7
# [22:30:11] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 176 extra nodes, 0 pruned nodes, max_depth=7
# [22:30:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 160 extra nodes, 0 pruned nodes, max_depth=7
# [22:30:13] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 162 extra nodes, 0 pruned nodes, max_depth=7
# [22:30:15] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 150 extra nodes, 0 pruned nodes, max_depth=7
# [22:30:16] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 166 extra nodes, 0 pruned nodes, max_depth=7
# [22:30:17] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 146 extra nodes, 0 pruned nodes, max_depth=7
# [22:30:18] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 142 extra nodes, 0 pruned nodes, max_depth=7
# [22:30:19] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 112 extra nodes, 0 pruned nodes, max_depth=7
# [22:30:20] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 194 extra nodes, 0 pruned nodes, max_depth=7
# [22:30:21] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 156 extra nodes, 0 pruned nodes, max_depth=7
# [22:30:22] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 158 extra nodes, 0 pruned nodes, max_depth=7
# [22:30:23] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 144 extra nodes, 0 pruned nodes, max_depth=7
# [22:30:24] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 138 extra nodes, 0 pruned nodes, max_depth=7
# [22:30:25] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 170 extra nodes, 0 pruned nodes, max_depth=7
# [22:30:26] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 168 extra nodes, 0 pruned nodes, max_depth=7
# [22:30:27] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 132 extra nodes, 0 pruned nodes, max_depth=7
# [22:30:28] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 164 extra nodes, 0 pruned nodes, max_depth=7
# [22:30:29] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 130 extra nodes, 0 pruned nodes, max_depth=7
# [22:30:30] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 132 extra nodes, 0 pruned nodes, max_depth=7
# [22:30:31] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 144 extra nodes, 0 pruned nodes, max_depth=7
# [22:30:32] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 114 extra nodes, 0 pruned nodes, max_depth=7
# [22:30:33] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 162 extra nodes, 0 pruned nodes, max_depth=7
# [22:30:34] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 170 extra nodes, 0 pruned nodes, max_depth=7
# [22:30:35] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 142 extra nodes, 0 pruned nodes, max_depth=7
# [22:30:36] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 116 extra nodes, 0 pruned nodes, max_depth=7
# [22:30:37] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 124 extra nodes, 0 pruned nodes, max_depth=7
# [22:30:38] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 134 extra nodes, 0 pruned nodes, max_depth=7
# [22:30:39] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 202 extra nodes, 0 pruned nodes, max_depth=7
# [22:30:40] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 136 extra nodes, 0 pruned nodes, max_depth=7
# [22:30:41] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 136 extra nodes, 0 pruned nodes, max_depth=7
# [22:30:42] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 138 extra nodes, 0 pruned nodes, max_depth=7
# [22:30:43] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 134 extra nodes, 0 pruned nodes, max_depth=7
# [22:30:44] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 140 extra nodes, 0 pruned nodes, max_depth=7
# [22:30:46] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 170 extra nodes, 0 pruned nodes, max_depth=7
# [22:30:47] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 176 extra nodes, 0 pruned nodes, max_depth=7
# [22:30:48] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 150 extra nodes, 0 pruned nodes, max_depth=7
# [22:30:49] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 184 extra nodes, 0 pruned nodes, max_depth=7
# [22:30:50] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 142 extra nodes, 0 pruned nodes, max_depth=7
# [22:30:51] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 124 extra nodes, 0 pruned nodes, max_depth=7
# [699]	train-auc:0.97767	valid-auc:0.88489
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-578b11f95276> in <module>
#      14     clf=xgb.train(param, trn_data, 700, evals=watchlist, early_stopping_rounds=250, verbose_eval=500)
#      15
# ---> 16     oof[valid_idx] = clf.predict(x_train[valid_idx], ntree_limit=clf.best_ntree_limit)
#      17
#      18     #fold_importance_df = pd.DataFrame()
#
# D:\Anaconda\lib\site-packages\xgboost\core.py in predict(self, data, output_margin, ntree_limit, pred_leaf, pred_contribs, approx_contribs, pred_interactions, validate_features)
#    1216
#    1217         if validate_features:
# -> 1218             self._validate_features(data)
#    1219
#    1220         length = c_bst_ulong()
#
# D:\Anaconda\lib\site-packages\xgboost\core.py in _validate_features(self, data)
#    1524         else:
#    1525             # Booster can't accept data with different feature names
# -> 1526             if self.feature_names != data.feature_names:
#    1527                 dat_missing = set(self.feature_names) - set(data.feature_names)
#    1528                 my_missing = set(data.feature_names) - set(self.feature_names)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'feature_names'

# %%
num_round = 15000
xgb_clf = xgb.train(param, d_train, num_round,watchlist, early_stopping_rounds=250, verbose_eval=100)
# Out:
# [14:09:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 2736 pruned nodes, max_depth=7
# [0]	train-auc:0.637763	valid-auc:0.627464
# Multiple eval metrics have been passed: 'valid-auc' will be used for early stopping.
#
# Will train until valid-auc hasn't improved in 250 rounds.
# [14:09:27] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2756 pruned nodes, max_depth=4
# [14:09:41] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 2846 pruned nodes, max_depth=6
# [14:09:55] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 2894 pruned nodes, max_depth=6
# [14:10:09] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 2738 pruned nodes, max_depth=7
# [14:10:23] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 3272 pruned nodes, max_depth=3
# [14:10:37] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 3028 pruned nodes, max_depth=5
# [14:10:52] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 2682 pruned nodes, max_depth=8
# [14:11:06] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 3176 pruned nodes, max_depth=6
# [14:11:20] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 2960 pruned nodes, max_depth=6
# [14:11:35] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 3224 pruned nodes, max_depth=6
# [14:11:49] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 3190 pruned nodes, max_depth=6
# [14:12:03] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 3132 pruned nodes, max_depth=7
# [14:12:18] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 3336 pruned nodes, max_depth=6
# [14:12:33] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 3308 pruned nodes, max_depth=7
# [14:12:48] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 3084 pruned nodes, max_depth=8
# [14:13:03] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 2734 pruned nodes, max_depth=9
# [14:13:19] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 3094 pruned nodes, max_depth=7
# [14:13:39] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 3086 pruned nodes, max_depth=9
# [14:13:58] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 3222 pruned nodes, max_depth=8
# [14:14:17] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 3224 pruned nodes, max_depth=7
# [14:14:33] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 2914 pruned nodes, max_depth=10
# [14:14:48] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 3122 pruned nodes, max_depth=9
# [14:15:04] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 3170 pruned nodes, max_depth=7
# [14:15:19] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 2790 pruned nodes, max_depth=9
# [14:15:34] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 3252 pruned nodes, max_depth=9
# [14:15:50] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 3396 pruned nodes, max_depth=7
# [14:16:06] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 2622 pruned nodes, max_depth=11
# [14:16:22] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 3226 pruned nodes, max_depth=8
# [14:16:39] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 3182 pruned nodes, max_depth=6
# [14:16:55] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 3230 pruned nodes, max_depth=7
# [14:17:11] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 3040 pruned nodes, max_depth=9
# [14:17:27] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 3368 pruned nodes, max_depth=7
# [14:17:42] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 3124 pruned nodes, max_depth=9
# [14:17:57] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 3156 pruned nodes, max_depth=9
# [14:18:13] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 2690 pruned nodes, max_depth=9
# [14:18:28] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 2966 pruned nodes, max_depth=8
# [14:18:44] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 3364 pruned nodes, max_depth=6
# [14:19:01] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 3840 pruned nodes, max_depth=6
# [14:19:17] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 3086 pruned nodes, max_depth=6
# [14:19:32] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 2828 pruned nodes, max_depth=8
# [14:19:48] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 4076 pruned nodes, max_depth=5
# [14:20:03] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 3146 pruned nodes, max_depth=8
# [14:20:19] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 3114 pruned nodes, max_depth=7
# [14:20:34] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 3858 pruned nodes, max_depth=6
# [14:20:50] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 3262 pruned nodes, max_depth=6
# [14:21:06] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 3366 pruned nodes, max_depth=6
# [14:21:22] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 3710 pruned nodes, max_depth=6
# [14:21:37] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 3854 pruned nodes, max_depth=4
# [14:21:53] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 3170 pruned nodes, max_depth=6
# [14:22:08] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 3718 pruned nodes, max_depth=4
# [14:22:24] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 3720 pruned nodes, max_depth=5
# [14:22:40] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 3634 pruned nodes, max_depth=6
# [14:22:56] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4066 pruned nodes, max_depth=4
# [14:23:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 3582 pruned nodes, max_depth=7
# [14:23:27] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 3112 pruned nodes, max_depth=7
# [14:23:42] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 2962 pruned nodes, max_depth=9
# [14:23:58] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 3488 pruned nodes, max_depth=5
# [14:24:13] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 3558 pruned nodes, max_depth=5
# [14:24:29] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 3600 pruned nodes, max_depth=4
# [14:24:45] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 2992 pruned nodes, max_depth=7
# [14:25:00] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 3052 pruned nodes, max_depth=7
# [14:25:18] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 3296 pruned nodes, max_depth=5
# [14:25:34] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 3176 pruned nodes, max_depth=8
# [14:25:49] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 3794 pruned nodes, max_depth=5
# [14:26:05] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 3808 pruned nodes, max_depth=3
# [14:26:21] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 3784 pruned nodes, max_depth=4
# [14:26:36] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 3186 pruned nodes, max_depth=5
# [14:26:52] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 3784 pruned nodes, max_depth=3
# [14:27:07] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 3252 pruned nodes, max_depth=6
# [14:27:23] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 3624 pruned nodes, max_depth=4
# [14:27:39] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 3892 pruned nodes, max_depth=3
# [14:27:55] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 3862 pruned nodes, max_depth=3
# [14:28:10] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 3658 pruned nodes, max_depth=5
# [14:28:26] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 3984 pruned nodes, max_depth=3
# [14:28:41] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 3170 pruned nodes, max_depth=7
# [14:28:56] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 3390 pruned nodes, max_depth=6
# [14:29:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 3598 pruned nodes, max_depth=4
# [14:29:28] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 3630 pruned nodes, max_depth=4
# [14:29:43] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 3114 pruned nodes, max_depth=4
# [14:29:59] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 3614 pruned nodes, max_depth=6
# [14:30:15] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 3480 pruned nodes, max_depth=5
# [14:30:32] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 4170 pruned nodes, max_depth=3
# [14:30:48] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 3270 pruned nodes, max_depth=6
# [14:31:03] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 3000 pruned nodes, max_depth=5
# [14:31:19] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 3568 pruned nodes, max_depth=5
# [14:31:34] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 2696 pruned nodes, max_depth=7
# [14:31:50] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 3032 pruned nodes, max_depth=5
# [14:32:06] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 3824 pruned nodes, max_depth=4
# [14:32:22] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4240 pruned nodes, max_depth=4
# [14:32:39] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 4102 pruned nodes, max_depth=2
# [14:32:55] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 4146 pruned nodes, max_depth=2
# [14:33:11] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 3760 pruned nodes, max_depth=3
# [14:33:26] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 2914 pruned nodes, max_depth=3
# [14:33:42] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 3150 pruned nodes, max_depth=4
# [14:33:58] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 3698 pruned nodes, max_depth=4
# [14:34:14] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 3770 pruned nodes, max_depth=4
# [14:34:30] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 4006 pruned nodes, max_depth=2
# [14:34:46] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 4012 pruned nodes, max_depth=3
# [14:35:01] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 3122 pruned nodes, max_depth=6
# [14:35:17] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 3966 pruned nodes, max_depth=2
# [100]	train-auc:0.869482	valid-auc:0.840578
# [14:35:33] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 3618 pruned nodes, max_depth=3
# [14:35:48] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 3204 pruned nodes, max_depth=4
# [14:36:05] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 3908 pruned nodes, max_depth=2
# [14:36:23] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 3350 pruned nodes, max_depth=4
# [14:36:39] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 3372 pruned nodes, max_depth=5
# [14:36:54] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2816 pruned nodes, max_depth=6
# [14:37:10] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 3510 pruned nodes, max_depth=3
# [14:37:26] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 3298 pruned nodes, max_depth=4
# [14:37:42] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 3466 pruned nodes, max_depth=2
# [14:37:57] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 3128 pruned nodes, max_depth=5
# [14:38:14] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 3256 pruned nodes, max_depth=5
# [14:38:30] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 3766 pruned nodes, max_depth=2
# [14:38:47] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 3992 pruned nodes, max_depth=3
# [14:39:03] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 3632 pruned nodes, max_depth=2
# [14:39:20] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 4116 pruned nodes, max_depth=2
# [14:39:35] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 3378 pruned nodes, max_depth=3
# [14:39:51] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 3584 pruned nodes, max_depth=2
# [14:40:08] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 3146 pruned nodes, max_depth=4
# [14:40:25] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 3472 pruned nodes, max_depth=2
# [14:40:43] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 3826 pruned nodes, max_depth=2
# [14:40:58] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 2526 pruned nodes, max_depth=7
# [14:41:16] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 3990 pruned nodes, max_depth=2
# [14:41:34] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 3762 pruned nodes, max_depth=3
# [14:41:53] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 4028 pruned nodes, max_depth=2
# [14:42:10] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 3214 pruned nodes, max_depth=4
# [14:42:27] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 3980 pruned nodes, max_depth=3
# [14:42:44] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 3448 pruned nodes, max_depth=5
# [14:43:00] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 3994 pruned nodes, max_depth=1
# [14:43:15] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 3006 pruned nodes, max_depth=5
# [14:43:33] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 4408 pruned nodes, max_depth=1
# [14:43:52] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 3874 pruned nodes, max_depth=1
# [14:44:10] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 3502 pruned nodes, max_depth=3
# [14:44:28] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 3362 pruned nodes, max_depth=4
# [14:44:45] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 4106 pruned nodes, max_depth=1
# [14:45:00] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2864 pruned nodes, max_depth=5
# [14:45:16] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 3654 pruned nodes, max_depth=1
# [14:45:32] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 3994 pruned nodes, max_depth=2
# [14:45:49] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 3414 pruned nodes, max_depth=3
# [14:46:06] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 4432 pruned nodes, max_depth=2
# [14:46:23] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 3928 pruned nodes, max_depth=3
# [14:46:39] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 3238 pruned nodes, max_depth=4
# [14:46:55] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 3560 pruned nodes, max_depth=1
# [14:47:10] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 3638 pruned nodes, max_depth=3
# [14:47:26] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 4180 pruned nodes, max_depth=1
# [14:47:45] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 4050 pruned nodes, max_depth=1
# [14:48:03] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 3322 pruned nodes, max_depth=2
# [14:48:19] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 3284 pruned nodes, max_depth=3
# [14:48:35] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 3626 pruned nodes, max_depth=1
# [14:48:52] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 3512 pruned nodes, max_depth=2
# [14:49:10] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 4668 pruned nodes, max_depth=1
# [14:49:27] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 3418 pruned nodes, max_depth=2
# [14:49:43] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 3022 pruned nodes, max_depth=2
# [14:50:00] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 4130 pruned nodes, max_depth=1
# [14:50:20] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 4592 pruned nodes, max_depth=1
# [14:50:35] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 3422 pruned nodes, max_depth=3
# [14:50:52] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 4330 pruned nodes, max_depth=1
# [14:51:07] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 3894 pruned nodes, max_depth=1
# [14:51:23] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 4148 pruned nodes, max_depth=2
# [14:51:39] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 3806 pruned nodes, max_depth=3
# [14:51:56] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 3786 pruned nodes, max_depth=1
# [14:52:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 3594 pruned nodes, max_depth=2
# [14:52:28] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 4158 pruned nodes, max_depth=1
# [14:52:45] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 4260 pruned nodes, max_depth=1
# [14:53:01] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 3428 pruned nodes, max_depth=2
# [14:53:18] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 3474 pruned nodes, max_depth=3
# [14:53:35] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 3602 pruned nodes, max_depth=1
# [14:53:54] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 4370 pruned nodes, max_depth=2
# [14:54:09] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 2910 pruned nodes, max_depth=3
# [14:54:25] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 3988 pruned nodes, max_depth=1
# [14:54:42] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 4272 pruned nodes, max_depth=1
# [14:54:57] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 3296 pruned nodes, max_depth=2
# [14:55:13] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 3850 pruned nodes, max_depth=1
# [14:55:29] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 3620 pruned nodes, max_depth=1
# [14:55:44] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 3510 pruned nodes, max_depth=2
# [14:56:00] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 3690 pruned nodes, max_depth=2
# [14:56:15] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 2962 pruned nodes, max_depth=4
# [14:56:30] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 3700 pruned nodes, max_depth=2
# [14:56:45] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 3090 pruned nodes, max_depth=1
# [14:57:01] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 3690 pruned nodes, max_depth=1
# [14:57:16] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 3478 pruned nodes, max_depth=2
# [14:57:32] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 3432 pruned nodes, max_depth=2
# [14:57:48] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 4064 pruned nodes, max_depth=1
# [14:58:04] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 3944 pruned nodes, max_depth=1
# [14:58:20] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [14:58:35] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [14:58:51] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [14:59:07] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [14:59:24] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [14:59:41] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [14:59:57] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:00:13] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:00:28] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:00:44] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:01:00] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:01:15] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:01:31] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:01:47] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:02:03] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:02:18] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:02:36] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [200]	train-auc:0.883188	valid-auc:0.856554
# [15:02:53] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:03:10] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:03:27] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:03:43] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:04:00] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:04:16] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:04:32] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:04:51] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:05:10] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:05:27] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:05:43] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:05:59] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:06:16] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:06:33] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:06:51] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:07:08] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:07:24] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:07:40] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:07:56] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:08:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:08:29] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:08:45] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:09:01] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:09:19] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:09:36] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:09:52] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:10:08] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:10:25] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:10:41] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:10:57] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:11:13] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:11:29] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:11:45] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:12:02] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:12:19] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:12:35] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:12:53] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:13:10] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:13:28] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:13:47] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:14:07] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:14:25] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:14:42] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:14:59] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:15:15] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:15:32] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:15:49] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:16:05] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:16:25] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:16:41] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:16:58] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:17:14] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:17:30] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:17:46] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:18:03] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:18:19] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:18:34] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:18:50] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:19:06] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:19:21] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:19:38] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:19:55] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:20:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:20:29] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:20:47] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:21:03] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:21:19] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:21:35] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:21:51] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:22:08] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:22:24] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:22:40] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:22:56] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:23:11] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:23:27] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:23:43] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:24:00] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:24:16] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:24:32] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:24:50] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:25:07] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:25:23] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:25:38] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:25:54] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:26:10] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:26:26] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:26:41] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:26:57] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:27:13] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:27:29] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:27:44] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:28:00] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:28:16] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:28:32] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:28:47] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:29:03] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:29:19] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:29:35] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:29:51] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:30:06] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [300]	train-auc:0.883188	valid-auc:0.856554
# [15:30:22] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:30:38] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:30:54] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:31:09] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:31:25] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:31:41] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:31:57] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:32:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:32:28] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:32:44] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# ...
# [15:38:47] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:39:03] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:39:19] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:39:36] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:39:54] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:40:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:40:29] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:40:45] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:41:01] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:41:16] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:41:32] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:41:48] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:42:03] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:42:19] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:42:35] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:42:51] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:43:06] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:43:22] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:43:39] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:43:54] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:44:10] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:44:26] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:44:41] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:44:57] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:45:13] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:45:28] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:45:44] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:46:00] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:46:17] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:46:32] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:46:48] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:47:04] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:47:20] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:47:35] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:47:51] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:48:07] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:48:23] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:48:39] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:48:55] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:49:11] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:49:26] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:49:42] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:49:58] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:50:13] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:50:29] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:50:45] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:51:01] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:51:17] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:51:32] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:51:48] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:52:04] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:52:20] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:52:36] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:52:52] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:53:07] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:53:24] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:53:39] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:53:55] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:54:10] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:54:26] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:54:42] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:54:58] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:55:14] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:55:29] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:55:45] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:56:05] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:56:24] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:56:43] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:57:01] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:57:18] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [400]	train-auc:0.883188	valid-auc:0.856554
# [15:57:35] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:57:52] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:58:09] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:58:27] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:58:45] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:59:02] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:59:20] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:59:38] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [15:59:56] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [16:00:14] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [16:00:31] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [16:00:49] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [16:01:07] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [16:01:25] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [16:01:43] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [16:02:01] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [16:02:19] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [16:02:37] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [16:02:55] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [16:03:13] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [16:03:30] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [16:03:48] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [16:04:06] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [16:04:24] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [16:04:42] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [16:05:00] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [16:05:18] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [16:05:36] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [16:05:54] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [16:06:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [16:06:30] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [16:06:48] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# [16:07:06] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 3578 pruned nodes, max_depth=0
# Stopping. Best iteration:
# [183]	train-auc:0.883188	valid-auc:0.856554

# %%
xgb_clf=clf
xgb_clf.save_model('xgb_clf_raw.model')

# %%
df=pd.DataFrame(list(xgb_clf.get_fscore().items()), columns=['feature','importance']).sort_values('importance', ascending=False)

# %% [markdown]
# ### Neural network

# %%
#https://www.kaggle.com/super13579/pytorch-nn-with-cyclelr-and-k-fold-lightgbm
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.autograd import Variable
from torch.utils.data import Dataset, DataLoader
import time

# %%
n_splits = 5 # Number of K-fold Splits

splits = list(StratifiedKFold(n_splits=n_splits, shuffle=True).split(train, y))

# %%
class CyclicLR(object):
    def __init__(self, optimizer, base_lr=1e-3, max_lr=6e-3,
                 step_size=2000, mode='triangular', gamma=1.,
                 scale_fn=None, scale_mode='cycle', last_batch_iteration=-1):

        if not isinstance(optimizer, Optimizer):
            raise TypeError('{} is not an Optimizer'.format(
                type(optimizer).__name__))
        self.optimizer = optimizer

        if isinstance(base_lr, list) or isinstance(base_lr, tuple):
            if len(base_lr) != len(optimizer.param_groups):
                raise ValueError("expected {} base_lr, got {}".format(
                    len(optimizer.param_groups), len(base_lr)))
            self.base_lrs = list(base_lr)
        else:
            self.base_lrs = [base_lr] * len(optimizer.param_groups)

        if isinstance(max_lr, list) or isinstance(max_lr, tuple):
            if len(max_lr) != len(optimizer.param_groups):
                raise ValueError("expected {} max_lr, got {}".format(
                    len(optimizer.param_groups), len(max_lr)))
            self.max_lrs = list(max_lr)
        else:
            self.max_lrs = [max_lr] * len(optimizer.param_groups)

        self.step_size = step_size

        if mode not in ['triangular', 'triangular2', 'exp_range'] \
                and scale_fn is None:
            raise ValueError('mode is invalid and scale_fn is None')

        self.mode = mode
        self.gamma = gamma

        if scale_fn is None:
            if self.mode == 'triangular':
                self.scale_fn = self._triangular_scale_fn
                self.scale_mode = 'cycle'
            elif self.mode == 'triangular2':
                self.scale_fn = self._triangular2_scale_fn
                self.scale_mode = 'cycle'
            elif self.mode == 'exp_range':
                self.scale_fn = self._exp_range_scale_fn
                self.scale_mode = 'iterations'
        else:
            self.scale_fn = scale_fn
            self.scale_mode = scale_mode

        self.batch_step(last_batch_iteration + 1)
        self.last_batch_iteration = last_batch_iteration

    def batch_step(self, batch_iteration=None):
        if batch_iteration is None:
            batch_iteration = self.last_batch_iteration + 1
        self.last_batch_iteration = batch_iteration
        for param_group, lr in zip(self.optimizer.param_groups, self.get_lr()):
            param_group['lr'] = lr

    def _triangular_scale_fn(self, x):
        return 1.

    def _triangular2_scale_fn(self, x):
        return 1 / (2. ** (x - 1))

    def _exp_range_scale_fn(self, x):
        return self.gamma**(x)

    def get_lr(self):
        step_size = float(self.step_size)
        cycle = np.floor(1 + self.last_batch_iteration / (2 * step_size))
        x = np.abs(self.last_batch_iteration / step_size - 2 * cycle + 1)

        lrs = []
        param_lrs = zip(self.optimizer.param_groups, self.base_lrs, self.max_lrs)
        for param_group, base_lr, max_lr in param_lrs:
            base_height = (max_lr - base_lr) * np.maximum(0, (1 - x))
            if self.scale_mode == 'cycle':
                lr = base_lr + base_height * self.scale_fn(cycle)
            else:
                lr = base_lr + base_height * self.scale_fn(self.last_batch_iteration)
            lrs.append(lr)
        return lrs

# %%
class Simple_NN(nn.Module):
    def __init__(self ,input_dim ,hidden_dim, dropout = 0.2):
        super(Simple_NN, self).__init__()
        
        self.inpt_dim = input_dim
        self.hidden_dim = hidden_dim
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(dropout)
        self.fc1 = nn.Linear(input_dim, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, int(hidden_dim/2))
        self.fc3 = nn.Linear(int(hidden_dim/2), int(hidden_dim/4))
        self.fc4 = nn.Linear(int(hidden_dim/4), int(hidden_dim/8))
        self.fc5 = nn.Linear(int(hidden_dim/8), 1)
        self.bn1 = nn.BatchNorm1d(hidden_dim)
        self.bn2 = nn.BatchNorm1d(int(hidden_dim/2))
        self.bn3 = nn.BatchNorm1d(int(hidden_dim/4))
        self.bn4 = nn.BatchNorm1d(int(hidden_dim/8))
    
    def forward(self, x):
        y = self.fc1(x)
        y = self.relu(y)
        #y = self.bn1(y)
        y = self.dropout(y)
        
        y = self.fc2(y)
        y = self.relu(y)
        #y = self.bn2(y)
        y = self.dropout(y)
        
        y = self.fc3(y)
        y = self.relu(y)
        #y = self.bn3(y)
        y = self.dropout(y)
        
        y = self.fc4(y)
        y = self.relu(y)
        #y = self.bn4(y)
        y = self.dropout(y)
        
        out= self.fc5(y)
        
        return out

# %%
model = Simple_NN(200,512)
model.cuda()
optimizer = torch.optim.Adam(model.parameters(), lr = 0.0002) # Using Adam optimizer

# %%
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

# %%
train_features=train
test_features=X_test
train_target=y

# %%
train_features.shape,test_features.shape,train_target.shape
# Out:
# ((200000, 200), (200000, 200), (200000,))

# %%
from torch.optim.optimizer import Optimizer
n_epochs = 40
batch_size = 25000

train_preds = np.zeros((len(train_features)))
test_preds = np.zeros((len(test_features)))

x_test = np.array(test_features)
x_test_cuda = torch.tensor(x_test, dtype=torch.float).cuda()
test = torch.utils.data.TensorDataset(x_test_cuda)
test_loader = torch.utils.data.DataLoader(test, batch_size=batch_size, shuffle=False)

avg_losses_f = []
avg_val_losses_f = []

for i, (train_idx, valid_idx) in enumerate(splits):  
    x_train = np.array(train_features)
    y_train = np.array(train_target)
    
    x_train_fold = torch.tensor(x_train[train_idx.astype(int)], dtype=torch.float).cuda()
    y_train_fold = torch.tensor(y_train[train_idx.astype(int), np.newaxis], dtype=torch.float32).cuda()
    
    x_val_fold = torch.tensor(x_train[valid_idx.astype(int)], dtype=torch.float).cuda()
    y_val_fold = torch.tensor(y_train[valid_idx.astype(int), np.newaxis], dtype=torch.float32).cuda()
    
    loss_fn = torch.nn.BCEWithLogitsLoss()
    
    step_size = 300
    base_lr, max_lr = 0.0001, 0.001  
    optimizer = torch.optim.Adam(filter(lambda p: p.requires_grad, model.parameters()), 
                             lr=max_lr)
    
    ################################################################################################
    scheduler = CyclicLR(optimizer, base_lr=base_lr, max_lr=max_lr,
               step_size=step_size, mode='exp_range',
               gamma=0.99994)
    ###############################################################################################

    train = torch.utils.data.TensorDataset(x_train_fold, y_train_fold)
    valid = torch.utils.data.TensorDataset(x_val_fold, y_val_fold)
    
    train_loader = torch.utils.data.DataLoader(train, batch_size=batch_size, shuffle=True)
    valid_loader = torch.utils.data.DataLoader(valid, batch_size=batch_size, shuffle=False)
    
    print(f'Fold {i + 1}')
    for epoch in range(n_epochs):
        start_time = time.time()
        model.train()
        avg_loss = 0.
        #avg_auc = 0.
        for i, (x_batch, y_batch) in enumerate(train_loader):
            y_pred = model(x_batch)
            #########################
            if scheduler:
                #print('cycle_LR')
                scheduler.batch_step()
            ########################
            loss = loss_fn(y_pred, y_batch)

            optimizer.zero_grad()
            loss.backward()

            optimizer.step()
            avg_loss += loss.item()/len(train_loader)
            #avg_auc += round(roc_auc_score(y_batch.cpu(),y_pred.detach().cpu()),4) / len(train_loader)
        model.eval()
        
        valid_preds_fold = np.zeros((x_val_fold.size(0)))
        test_preds_fold = np.zeros((len(test_features)))
        
        avg_val_loss = 0.
        #avg_val_auc = 0.
        for i, (x_batch, y_batch) in enumerate(valid_loader):
            y_pred = model(x_batch).detach()
            
            #avg_val_auc += round(roc_auc_score(y_batch.cpu(),sigmoid(y_pred.cpu().numpy())[:, 0]),4) / len(valid_loader)
            avg_val_loss += loss_fn(y_pred, y_batch).item() / len(valid_loader)
            valid_preds_fold[i * batch_size:(i+1) * batch_size] = sigmoid(y_pred.cpu().numpy())[:, 0]
            
        elapsed_time = time.time() - start_time 
        print('Epoch {}/{} \t loss={:.4f} \t val_loss={:.4f} \t time={:.2f}s'.format(
            epoch + 1, n_epochs, avg_loss, avg_val_loss, elapsed_time))
        
    avg_losses_f.append(avg_loss)
    avg_val_losses_f.append(avg_val_loss) 
    
    for i, (x_batch,) in enumerate(test_loader):
        y_pred = model(x_batch).detach()

        test_preds_fold[i * batch_size:(i+1) * batch_size] = sigmoid(y_pred.cpu().numpy())[:, 0]
        
    train_preds[valid_idx] = valid_preds_fold
    test_preds += test_preds_fold / len(splits)

auc  =  round(roc_auc_score(train_target,train_preds),4)      
print('All \t loss={:.4f} \t val_loss={:.4f} \t auc={:.4f}'.format(np.average(avg_losses_f),np.average(avg_val_losses_f),auc))
# Out:
# Fold 1
# Epoch 1/40 	 loss=0.5072 	 val_loss=0.3813 	 time=7.68s
# Epoch 2/40 	 loss=0.3498 	 val_loss=0.3352 	 time=7.47s
# Epoch 3/40 	 loss=0.3552 	 val_loss=0.3282 	 time=7.53s
# Epoch 4/40 	 loss=0.3372 	 val_loss=0.3297 	 time=7.47s
# Epoch 5/40 	 loss=0.3374 	 val_loss=0.3252 	 time=7.55s
# Epoch 6/40 	 loss=0.3309 	 val_loss=0.3186 	 time=7.47s
# Epoch 7/40 	 loss=0.3301 	 val_loss=0.3162 	 time=7.50s
# Epoch 8/40 	 loss=0.3256 	 val_loss=0.3127 	 time=7.49s
# Epoch 9/40 	 loss=0.3206 	 val_loss=0.3053 	 time=7.47s
# Epoch 10/40 	 loss=0.3128 	 val_loss=0.2953 	 time=7.48s
# Epoch 11/40 	 loss=0.3018 	 val_loss=0.2840 	 time=7.49s
# Epoch 12/40 	 loss=0.2924 	 val_loss=0.2745 	 time=7.49s
# Epoch 13/40 	 loss=0.2850 	 val_loss=0.2682 	 time=7.51s
# Epoch 14/40 	 loss=0.2772 	 val_loss=0.2639 	 time=7.45s
# Epoch 15/40 	 loss=0.2746 	 val_loss=0.2593 	 time=7.50s
# Epoch 16/40 	 loss=0.2723 	 val_loss=0.2567 	 time=7.50s
# Epoch 17/40 	 loss=0.2685 	 val_loss=0.2546 	 time=7.56s
# Epoch 18/40 	 loss=0.2657 	 val_loss=0.2532 	 time=7.46s
# Epoch 19/40 	 loss=0.2628 	 val_loss=0.2508 	 time=7.52s
# Epoch 20/40 	 loss=0.2616 	 val_loss=0.2519 	 time=7.44s
# Epoch 21/40 	 loss=0.2605 	 val_loss=0.2489 	 time=7.43s
# Epoch 22/40 	 loss=0.2562 	 val_loss=0.2478 	 time=7.50s
# Epoch 23/40 	 loss=0.2571 	 val_loss=0.2492 	 time=7.44s
# Epoch 24/40 	 loss=0.2551 	 val_loss=0.2460 	 time=7.47s
# Epoch 25/40 	 loss=0.2523 	 val_loss=0.2454 	 time=7.45s
# Epoch 26/40 	 loss=0.2519 	 val_loss=0.2470 	 time=7.46s
# Epoch 27/40 	 loss=0.2509 	 val_loss=0.2547 	 time=7.46s
# Epoch 28/40 	 loss=0.2560 	 val_loss=0.2458 	 time=7.42s
# Epoch 29/40 	 loss=0.2513 	 val_loss=0.2433 	 time=7.51s
# Epoch 30/40 	 loss=0.2466 	 val_loss=0.2438 	 time=7.50s
# Epoch 31/40 	 loss=0.2459 	 val_loss=0.2431 	 time=7.45s
# Epoch 32/40 	 loss=0.2437 	 val_loss=0.2454 	 time=7.55s
# Epoch 33/40 	 loss=0.2457 	 val_loss=0.2440 	 time=7.51s
# Epoch 34/40 	 loss=0.2488 	 val_loss=0.2430 	 time=7.48s
# Epoch 35/40 	 loss=0.2432 	 val_loss=0.2421 	 time=7.46s
# Epoch 36/40 	 loss=0.2395 	 val_loss=0.2489 	 time=7.60s
# Epoch 37/40 	 loss=0.2385 	 val_loss=0.2502 	 time=7.54s
# Epoch 38/40 	 loss=0.2446 	 val_loss=0.2474 	 time=7.49s
# Epoch 39/40 	 loss=0.2400 	 val_loss=0.2432 	 time=7.66s
# Epoch 40/40 	 loss=0.2348 	 val_loss=0.2448 	 time=7.50s
# Fold 2
# Epoch 1/40 	 loss=0.2386 	 val_loss=0.2218 	 time=7.50s
# Epoch 2/40 	 loss=0.2365 	 val_loss=0.2211 	 time=7.35s
# Epoch 3/40 	 loss=0.2356 	 val_loss=0.2215 	 time=7.34s
# Epoch 4/40 	 loss=0.2347 	 val_loss=0.2217 	 time=7.32s
# Epoch 5/40 	 loss=0.2347 	 val_loss=0.2209 	 time=7.31s
# Epoch 6/40 	 loss=0.2342 	 val_loss=0.2206 	 time=7.35s
# Epoch 7/40 	 loss=0.2332 	 val_loss=0.2207 	 time=7.35s
# Epoch 8/40 	 loss=0.2327 	 val_loss=0.2215 	 time=7.29s
# Epoch 9/40 	 loss=0.2322 	 val_loss=0.2208 	 time=7.41s
# Epoch 10/40 	 loss=0.2321 	 val_loss=0.2216 	 time=7.30s
# Epoch 11/40 	 loss=0.2316 	 val_loss=0.2256 	 time=7.44s
# Epoch 12/40 	 loss=0.2328 	 val_loss=0.2220 	 time=7.24s
# Epoch 13/40 	 loss=0.2335 	 val_loss=0.2243 	 time=7.35s
# Epoch 14/40 	 loss=0.2307 	 val_loss=0.2245 	 time=7.35s
# Epoch 15/40 	 loss=0.2274 	 val_loss=0.2236 	 time=7.29s
# Epoch 16/40 	 loss=0.2286 	 val_loss=0.2212 	 time=7.33s
# Epoch 17/40 	 loss=0.2264 	 val_loss=0.2233 	 time=7.32s
# Epoch 18/40 	 loss=0.2243 	 val_loss=0.2216 	 time=9.22s
# Epoch 19/40 	 loss=0.2250 	 val_loss=0.2216 	 time=7.32s
# Epoch 20/40 	 loss=0.2245 	 val_loss=0.2221 	 time=7.26s
# Epoch 21/40 	 loss=0.2219 	 val_loss=0.2254 	 time=7.36s
# Epoch 22/40 	 loss=0.2212 	 val_loss=0.2225 	 time=7.32s
# Epoch 23/40 	 loss=0.2195 	 val_loss=0.2242 	 time=7.31s
# Epoch 24/40 	 loss=0.2188 	 val_loss=0.2306 	 time=7.28s
# Epoch 25/40 	 loss=0.2183 	 val_loss=0.2383 	 time=7.51s
# Epoch 26/40 	 loss=0.2254 	 val_loss=0.2262 	 time=7.63s
# Epoch 27/40 	 loss=0.2190 	 val_loss=0.2254 	 time=7.50s
# Epoch 28/40 	 loss=0.2163 	 val_loss=0.2346 	 time=7.47s
# Epoch 29/40 	 loss=0.2181 	 val_loss=0.2270 	 time=7.54s
# Epoch 30/40 	 loss=0.2154 	 val_loss=0.2281 	 time=7.52s
# Epoch 31/40 	 loss=0.2119 	 val_loss=0.2269 	 time=7.48s
# Epoch 32/40 	 loss=0.2097 	 val_loss=0.2377 	 time=7.53s
# Epoch 33/40 	 loss=0.2084 	 val_loss=0.2316 	 time=7.50s
# Epoch 34/40 	 loss=0.2118 	 val_loss=0.2300 	 time=7.49s
# Epoch 35/40 	 loss=0.2098 	 val_loss=0.2416 	 time=7.49s
# Epoch 36/40 	 loss=0.2010 	 val_loss=0.2318 	 time=7.73s
# Epoch 37/40 	 loss=0.2011 	 val_loss=0.2530 	 time=7.55s
# Epoch 38/40 	 loss=0.2060 	 val_loss=0.2429 	 time=7.48s
# Epoch 39/40 	 loss=0.2162 	 val_loss=0.2344 	 time=7.55s
# Epoch 40/40 	 loss=0.2017 	 val_loss=0.2350 	 time=7.51s
# Fold 3
# Epoch 1/40 	 loss=0.2119 	 val_loss=0.1778 	 time=7.52s
# Epoch 2/40 	 loss=0.2062 	 val_loss=0.1726 	 time=7.61s
# Epoch 3/40 	 loss=0.2058 	 val_loss=0.1724 	 time=7.28s
# Epoch 4/40 	 loss=0.2064 	 val_loss=0.1741 	 time=7.32s
# Epoch 5/40 	 loss=0.2049 	 val_loss=0.1754 	 time=7.32s
# Epoch 6/40 	 loss=0.2041 	 val_loss=0.1733 	 time=7.35s
# Epoch 7/40 	 loss=0.2014 	 val_loss=0.1742 	 time=7.27s
# Epoch 8/40 	 loss=0.2012 	 val_loss=0.1714 	 time=7.50s
# Epoch 9/40 	 loss=0.2015 	 val_loss=0.1771 	 time=7.28s
# Epoch 10/40 	 loss=0.2009 	 val_loss=0.1736 	 time=7.30s
# Epoch 11/40 	 loss=0.1996 	 val_loss=0.1749 	 time=7.32s
# Epoch 12/40 	 loss=0.1991 	 val_loss=0.1827 	 time=7.33s
# Epoch 13/40 	 loss=0.1979 	 val_loss=0.1738 	 time=7.35s
# Epoch 14/40 	 loss=0.1965 	 val_loss=0.1749 	 time=7.36s
# Epoch 15/40 	 loss=0.1982 	 val_loss=0.1800 	 time=7.29s
# Epoch 16/40 	 loss=0.1953 	 val_loss=0.1863 	 time=7.34s
# Epoch 17/40 	 loss=0.1921 	 val_loss=0.1800 	 time=7.27s
# Epoch 18/40 	 loss=0.1902 	 val_loss=0.1782 	 time=7.38s
# Epoch 19/40 	 loss=0.1884 	 val_loss=0.1768 	 time=7.33s
# Epoch 20/40 	 loss=0.1885 	 val_loss=0.1828 	 time=7.33s
# Epoch 21/40 	 loss=0.1887 	 val_loss=0.1905 	 time=7.34s
# Epoch 22/40 	 loss=0.1840 	 val_loss=0.1831 	 time=7.29s
# Epoch 23/40 	 loss=0.1847 	 val_loss=0.1930 	 time=7.33s
# Epoch 24/40 	 loss=0.1840 	 val_loss=0.1827 	 time=7.31s
# Epoch 25/40 	 loss=0.1826 	 val_loss=0.1825 	 time=7.36s
# Epoch 26/40 	 loss=0.1780 	 val_loss=0.1925 	 time=7.29s
# Epoch 27/40 	 loss=0.1777 	 val_loss=0.1851 	 time=7.38s
# Epoch 28/40 	 loss=0.1779 	 val_loss=0.1884 	 time=7.44s
# Epoch 29/40 	 loss=0.1731 	 val_loss=0.1882 	 time=7.52s
# Epoch 30/40 	 loss=0.1726 	 val_loss=0.2022 	 time=7.48s
# Epoch 31/40 	 loss=0.1749 	 val_loss=0.1919 	 time=7.49s
# Epoch 32/40 	 loss=0.1710 	 val_loss=0.1986 	 time=7.57s
# Epoch 33/40 	 loss=0.1676 	 val_loss=0.1984 	 time=7.47s
# Epoch 34/40 	 loss=0.1677 	 val_loss=0.1929 	 time=7.46s
# Epoch 35/40 	 loss=0.1643 	 val_loss=0.1970 	 time=7.49s
# Epoch 36/40 	 loss=0.1617 	 val_loss=0.1980 	 time=7.53s
# Epoch 37/40 	 loss=0.1609 	 val_loss=0.1998 	 time=7.51s
# Epoch 38/40 	 loss=0.1649 	 val_loss=0.2149 	 time=7.43s
# Epoch 39/40 	 loss=0.1632 	 val_loss=0.2125 	 time=7.53s
# Epoch 40/40 	 loss=0.1547 	 val_loss=0.2075 	 time=7.47s
# Fold 4
# Epoch 1/40 	 loss=0.1740 	 val_loss=0.1157 	 time=7.56s
# Epoch 2/40 	 loss=0.1694 	 val_loss=0.1166 	 time=7.48s
# Epoch 3/40 	 loss=0.1682 	 val_loss=0.1164 	 time=7.48s
# Epoch 4/40 	 loss=0.1682 	 val_loss=0.1185 	 time=7.54s
# Epoch 5/40 	 loss=0.1656 	 val_loss=0.1184 	 time=7.51s
# Epoch 6/40 	 loss=0.1649 	 val_loss=0.1137 	 time=7.48s
# Epoch 7/40 	 loss=0.1639 	 val_loss=0.1195 	 time=7.50s
# Epoch 8/40 	 loss=0.1621 	 val_loss=0.1171 	 time=7.49s
# Epoch 9/40 	 loss=0.1612 	 val_loss=0.1169 	 time=7.50s
# Epoch 10/40 	 loss=0.1600 	 val_loss=0.1207 	 time=7.54s
# Epoch 11/40 	 loss=0.1599 	 val_loss=0.1259 	 time=7.47s
# Epoch 12/40 	 loss=0.1573 	 val_loss=0.1189 	 time=7.49s
# Epoch 13/40 	 loss=0.1562 	 val_loss=0.1180 	 time=7.50s
# Epoch 14/40 	 loss=0.1539 	 val_loss=0.1157 	 time=7.58s
# Epoch 15/40 	 loss=0.1554 	 val_loss=0.1232 	 time=7.52s
# Epoch 16/40 	 loss=0.1527 	 val_loss=0.1242 	 time=7.48s
# Epoch 17/40 	 loss=0.1519 	 val_loss=0.1219 	 time=7.49s
# Epoch 18/40 	 loss=0.1502 	 val_loss=0.1238 	 time=7.50s
# Epoch 19/40 	 loss=0.1489 	 val_loss=0.1343 	 time=7.46s
# Epoch 20/40 	 loss=0.1458 	 val_loss=0.1293 	 time=7.53s
# Epoch 21/40 	 loss=0.1445 	 val_loss=0.1349 	 time=7.49s
# Epoch 22/40 	 loss=0.1449 	 val_loss=0.1307 	 time=7.46s
# Epoch 23/40 	 loss=0.1454 	 val_loss=0.1347 	 time=7.56s
# Epoch 24/40 	 loss=0.1420 	 val_loss=0.1388 	 time=7.33s
# Epoch 25/40 	 loss=0.1396 	 val_loss=0.1336 	 time=7.31s
# Epoch 26/40 	 loss=0.1393 	 val_loss=0.1558 	 time=7.37s
# Epoch 27/40 	 loss=0.1492 	 val_loss=0.1497 	 time=7.31s
# Epoch 28/40 	 loss=0.1522 	 val_loss=0.1447 	 time=7.32s
# Epoch 29/40 	 loss=0.1454 	 val_loss=0.1448 	 time=7.29s
# Epoch 30/40 	 loss=0.1394 	 val_loss=0.1457 	 time=7.41s
# Epoch 31/40 	 loss=0.1326 	 val_loss=0.1446 	 time=7.31s
# Epoch 32/40 	 loss=0.1293 	 val_loss=0.1440 	 time=7.36s
# Epoch 33/40 	 loss=0.1305 	 val_loss=0.1455 	 time=7.28s
# Epoch 34/40 	 loss=0.1291 	 val_loss=0.1627 	 time=7.34s
# Epoch 35/40 	 loss=0.1277 	 val_loss=0.1656 	 time=7.27s
# Epoch 36/40 	 loss=0.1268 	 val_loss=0.1522 	 time=7.32s
# Epoch 37/40 	 loss=0.1248 	 val_loss=0.1551 	 time=7.31s
# Epoch 38/40 	 loss=0.1220 	 val_loss=0.1587 	 time=7.31s
# Epoch 39/40 	 loss=0.1210 	 val_loss=0.1629 	 time=7.28s
# Epoch 40/40 	 loss=0.1196 	 val_loss=0.1647 	 time=7.54s
# Fold 5
# Epoch 1/40 	 loss=0.1425 	 val_loss=0.0684 	 time=7.91s
# Epoch 2/40 	 loss=0.1385 	 val_loss=0.0730 	 time=7.74s
# Epoch 3/40 	 loss=0.1369 	 val_loss=0.0705 	 time=7.76s
# Epoch 4/40 	 loss=0.1347 	 val_loss=0.0727 	 time=7.37s
# Epoch 5/40 	 loss=0.1335 	 val_loss=0.0712 	 time=7.34s
# Epoch 6/40 	 loss=0.1330 	 val_loss=0.0702 	 time=7.36s
# Epoch 7/40 	 loss=0.1320 	 val_loss=0.0716 	 time=7.34s
# Epoch 8/40 	 loss=0.1294 	 val_loss=0.0710 	 time=7.33s
# Epoch 9/40 	 loss=0.1290 	 val_loss=0.0737 	 time=7.32s
# Epoch 10/40 	 loss=0.1272 	 val_loss=0.0720 	 time=7.29s
# Epoch 11/40 	 loss=0.1266 	 val_loss=0.0744 	 time=7.34s
# Epoch 12/40 	 loss=0.1259 	 val_loss=0.0775 	 time=7.34s
# Epoch 13/40 	 loss=0.1244 	 val_loss=0.0720 	 time=7.38s
# Epoch 14/40 	 loss=0.1245 	 val_loss=0.0751 	 time=7.31s
# Epoch 15/40 	 loss=0.1225 	 val_loss=0.0802 	 time=7.33s
# Epoch 16/40 	 loss=0.1215 	 val_loss=0.0821 	 time=7.35s
# Epoch 17/40 	 loss=0.1213 	 val_loss=0.0787 	 time=7.31s
# Epoch 18/40 	 loss=0.1200 	 val_loss=0.0890 	 time=7.38s
# Epoch 19/40 	 loss=0.1191 	 val_loss=0.0799 	 time=7.33s
# Epoch 20/40 	 loss=0.1170 	 val_loss=0.0813 	 time=7.35s
# Epoch 21/40 	 loss=0.1178 	 val_loss=0.0936 	 time=7.32s
# Epoch 22/40 	 loss=0.1189 	 val_loss=0.0873 	 time=7.34s
# Epoch 23/40 	 loss=0.1174 	 val_loss=0.0818 	 time=7.54s
# Epoch 24/40 	 loss=0.1154 	 val_loss=0.0849 	 time=7.86s
# Epoch 25/40 	 loss=0.1127 	 val_loss=0.0861 	 time=8.58s
# Epoch 26/40 	 loss=0.1139 	 val_loss=0.1030 	 time=7.93s
# Epoch 27/40 	 loss=0.1120 	 val_loss=0.0951 	 time=8.23s
# Epoch 28/40 	 loss=0.1108 	 val_loss=0.0943 	 time=9.10s
# Epoch 29/40 	 loss=0.1095 	 val_loss=0.0915 	 time=8.70s
# Epoch 30/40 	 loss=0.1108 	 val_loss=0.1110 	 time=8.49s
# Epoch 31/40 	 loss=0.1092 	 val_loss=0.0990 	 time=8.10s
# Epoch 32/40 	 loss=0.1071 	 val_loss=0.1094 	 time=8.24s
# Epoch 33/40 	 loss=0.1074 	 val_loss=0.1026 	 time=8.18s
# Epoch 34/40 	 loss=0.1063 	 val_loss=0.1055 	 time=8.88s
# Epoch 35/40 	 loss=0.1044 	 val_loss=0.1065 	 time=8.93s
# Epoch 36/40 	 loss=0.1042 	 val_loss=0.1064 	 time=8.67s
# Epoch 37/40 	 loss=0.1026 	 val_loss=0.1204 	 time=8.78s
# Epoch 38/40 	 loss=0.1037 	 val_loss=0.1140 	 time=8.17s
# Epoch 39/40 	 loss=0.1035 	 val_loss=0.1306 	 time=8.52s
# Epoch 40/40 	 loss=0.1034 	 val_loss=0.1319 	 time=8.29s
# All 	 loss=0.1628 	 val_loss=0.1968 	 auc=0.9061

# %%
torch.save(model.state_dict(), 'simple nn' )

# %%
#load on gpu
#device = torch.device("cuda")
#model = TheModelClass(*args, **kwargs)
#model.load_state_dict(torch.load(PATH))
#model.to(device)
# Make sure to call input = input.to(device) on any input tensors that you feed to the model

# %% [markdown]
# ### Tensorflow

# %%
import tensorflow as tf

# %%
he_init = tf.variance_scaling_initializer()

def dnn(inputs, n_hidden_layers=2, n_neurons=100, name=None,
        activation=tf.nn.elu, initializer=he_init):
    with tf.variable_scope(name, "dnn"):
        for layer in range(n_hidden_layers):
            inputs = tf.layers.dense(inputs, n_neurons, activation=activation,
                                     kernel_initializer=initializer,
                                     name="hidden%d" % (layer + 1))
        return inputs

# %%
n_inputs = 200
n_outputs = 2

#reset_graph()

X = tf.placeholder(tf.float32, shape=(None, n_inputs), name="X")
y = tf.placeholder(tf.int32, shape=(None), name="y")

dnn_outputs = dnn(X)

logits = tf.layers.dense(dnn_outputs, n_outputs, kernel_initializer=he_init, name="logits")
Y_proba = tf.nn.softmax(logits, name="Y_proba")
# Out:
# WARNING:tensorflow:From <ipython-input-7-f4647b674975>:9: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# WARNING:tensorflow:From D:\Anaconda\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
learning_rate = 0.01

xentropy = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=y, logits=logits)
loss = tf.reduce_mean(xentropy, name="loss")

optimizer = tf.train.AdamOptimizer(learning_rate)
training_op = optimizer.minimize(loss, name="training_op")

correct = tf.nn.in_top_k(logits, y, 1)
accuracy = tf.reduce_mean(tf.cast(correct, tf.float32), name="accuracy")

init = tf.global_variables_initializer()
saver = tf.train.Saver()

# %%
n_epochs = 1000
batch_size = 200

max_checks_without_progress = 20
checks_without_progress = 0
best_loss = np.infty

with tf.Session() as sess:
    init.run()

    for epoch in range(n_epochs):
        start_pos=0
        for batches in range(int(len(X_train)/batch_size)):
            X_batch,y_batch=X_train[start_pos:start_pos+batch_size],y_train[start_pos:start_pos+batch_size]
            sess.run(training_op, feed_dict={X: X_batch, y: y_batch})
            start_pos+=batch_size
        #rnd_idx = np.random.permutation(len(X_train))
        #for rnd_indices in np.array_split(rnd_idx, len(X_train) // batch_size):
            #X_batch, y_batch = X_train[rnd_indices], y_train[rnd_indices]
            #sess.run(training_op, feed_dict={X: X_batch, y: y_batch})
        loss_val, acc_val = sess.run([loss, accuracy], feed_dict={X: X_valid, y: y_valid})
        if loss_val < best_loss:
            save_path = saver.save(sess, "./MLP.ckpt")
            best_loss = loss_val
            checks_without_progress = 0
        else:
            checks_without_progress += 1
            if checks_without_progress > max_checks_without_progress:
                print("Early stopping!")
                break
        print("{}\tValidation loss: {:.6f}\tBest loss: {:.6f}\tAccuracy: {:.2f}%".format(
            epoch, loss_val, best_loss, acc_val * 100))

with tf.Session() as sess:
    saver.restore(sess, "./MLP.ckpt")
    acc_test = accuracy.eval(feed_dict={X: X_valid, y: y_valid})
    print("Final test accuracy: {:.2f}%".format(acc_test * 100))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-af5a97eeffc3> in <module>
#      11     for epoch in range(n_epochs):
#      12         start_pos=0
# ---> 13         for batches in range(int(len(X_train)/batch_size)):
#      14             X_batch,y_batch=X_train[start_pos:start_pos+batch_size],y_train[start_pos:start_pos+batch_size]
#      15             sess.run(training_op, feed_dict={X: X_batch, y: y_batch})
#
# NameError: name 'X_train' is not defined

# %%
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.exceptions import NotFittedError

class DNNClassifier(BaseEstimator, ClassifierMixin):
    def __init__(self, n_hidden_layers=5, n_neurons=100, optimizer_class=tf.train.AdamOptimizer,
                 learning_rate=0.01, batch_size=20, activation=tf.nn.elu, initializer=he_init,
                 batch_norm_momentum=None, dropout_rate=None, random_state=None):
        """Initialize the DNNClassifier by simply storing all the hyperparameters."""
        self.n_hidden_layers = n_hidden_layers
        self.n_neurons = n_neurons
        self.optimizer_class = optimizer_class
        self.learning_rate = learning_rate
        self.batch_size = batch_size
        self.activation = activation
        self.initializer = initializer
        self.batch_norm_momentum = batch_norm_momentum
        self.dropout_rate = dropout_rate
        self.random_state = random_state
        self._session = None

    def _dnn(self, inputs):
        """Build the hidden layers, with support for batch normalization and dropout."""
        for layer in range(self.n_hidden_layers):
            if self.dropout_rate:
                inputs = tf.layers.dropout(inputs, self.dropout_rate, training=self._training)
            inputs = tf.layers.dense(inputs, self.n_neurons,
                                     kernel_initializer=self.initializer,
                                     name="hidden%d" % (layer + 1))
            if self.batch_norm_momentum:
                inputs = tf.layers.batch_normalization(inputs, momentum=self.batch_norm_momentum,
                                                       training=self._training)
            inputs = self.activation(inputs, name="hidden%d_out" % (layer + 1))
        return inputs

    def _build_graph(self, n_inputs, n_outputs):
        """Build the same model as earlier"""
        if self.random_state is not None:
            tf.set_random_seed(self.random_state)
            np.random.seed(self.random_state)

        X = tf.placeholder(tf.float32, shape=(None, n_inputs), name="X")
        y = tf.placeholder(tf.int32, shape=(None), name="y")

        if self.batch_norm_momentum or self.dropout_rate:
            self._training = tf.placeholder_with_default(False, shape=(), name='training')
        else:
            self._training = None

        dnn_outputs = self._dnn(X)

        logits = tf.layers.dense(dnn_outputs, n_outputs, kernel_initializer=he_init, name="logits")
        Y_proba = tf.nn.softmax(logits, name="Y_proba")

        xentropy = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=y,
                                                                  logits=logits)
        loss = tf.reduce_mean(xentropy, name="loss")

        optimizer = self.optimizer_class(learning_rate=self.learning_rate)
        training_op = optimizer.minimize(loss)

        correct = tf.nn.in_top_k(logits, y, 1)
        accuracy = tf.reduce_mean(tf.cast(correct, tf.float32), name="accuracy")

        init = tf.global_variables_initializer()
        saver = tf.train.Saver()

        # Make the important operations available easily through instance variables
        self._X, self._y = X, y
        self._Y_proba, self._loss = Y_proba, loss
        self._training_op, self._accuracy = training_op, accuracy
        self._init, self._saver = init, saver

    def close_session(self):
        if self._session:
            self._session.close()

    def _get_model_params(self):
        """Get all variable values (used for early stopping, faster than saving to disk)"""
        with self._graph.as_default():
            gvars = tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES)
        return {gvar.op.name: value for gvar, value in zip(gvars, self._session.run(gvars))}

    def _restore_model_params(self, model_params):
        """Set all variables to the given values (for early stopping, faster than loading from disk)"""
        gvar_names = list(model_params.keys())
        assign_ops = {gvar_name: self._graph.get_operation_by_name(gvar_name + "/Assign")
                      for gvar_name in gvar_names}
        init_values = {gvar_name: assign_op.inputs[1] for gvar_name, assign_op in assign_ops.items()}
        feed_dict = {init_values[gvar_name]: model_params[gvar_name] for gvar_name in gvar_names}
        self._session.run(assign_ops, feed_dict=feed_dict)

    def fit(self, X, y, n_epochs=100, X_valid=None, y_valid=None):
        """Fit the model to the training set. If X_valid and y_valid are provided, use early stopping."""
        self.close_session()

        # infer n_inputs and n_outputs from the training set.
        n_inputs = X.shape[1]
        self.classes_ = np.unique(y)
        n_outputs = len(self.classes_)
        
        # Translate the labels vector to a vector of sorted class indices, containing
        # integers from 0 to n_outputs - 1.
        # For example, if y is equal to [8, 8, 9, 5, 7, 6, 6, 6], then the sorted class
        # labels (self.classes_) will be equal to [5, 6, 7, 8, 9], and the labels vector
        # will be translated to [3, 3, 4, 0, 2, 1, 1, 1]
        self.class_to_index_ = {label: index
                                for index, label in enumerate(self.classes_)}
        y = np.array([self.class_to_index_[label]
                      for label in y], dtype=np.int32)
        
        self._graph = tf.Graph()
        with self._graph.as_default():
            self._build_graph(n_inputs, n_outputs)
            # extra ops for batch normalization
            extra_update_ops = tf.get_collection(tf.GraphKeys.UPDATE_OPS)

        # needed in case of early stopping
        max_checks_without_progress = 20
        checks_without_progress = 0
        best_loss = np.infty
        best_params = None
        
        # Now train the model!
        self._session = tf.Session(graph=self._graph)
        with self._session.as_default() as sess:
            self._init.run()
            for epoch in range(n_epochs):
                start_pos=0
                for batches in range(int(len(X)/self.batch_size)):
                    X_batch,y_batch=X[start_pos:start_pos+self.batch_size],y[start_pos:start_pos+self.batch_size]
                    feed_dict = {self._X: X_batch, self._y: y_batch}
                    start_pos+=self.batch_size
                #rnd_idx = np.random.permutation(len(X))
                #for rnd_indices in np.array_split(rnd_idx, len(X) // self.batch_size):
                    #X_batch, y_batch = X[rnd_indices], y[rnd_indices]
                    #feed_dict = {self._X: X_batch, self._y: y_batch}
                    if self._training is not None:
                        feed_dict[self._training] = True
                    sess.run(self._training_op, feed_dict=feed_dict)
                    if extra_update_ops:
                        sess.run(extra_update_ops, feed_dict=feed_dict)
                if X_valid is not None and y_valid is not None:
                    loss_val, acc_val = sess.run([self._loss, self._accuracy],
                                                 feed_dict={self._X: X_valid,
                                                            self._y: y_valid})
                    if loss_val < best_loss:
                        best_params = self._get_model_params()
                        best_loss = loss_val
                        checks_without_progress = 0
                    else:
                        checks_without_progress += 1
                    print("{}\tValidation loss: {:.6f}\tBest loss: {:.6f}\tAccuracy: {:.2f}%".format(
                        epoch, loss_val, best_loss, acc_val * 100))
                    if checks_without_progress > max_checks_without_progress:
                        print("Early stopping!")
                        break
                else:
                    loss_train, acc_train = sess.run([self._loss, self._accuracy],
                                                     feed_dict={self._X: X_batch,
                                                                self._y: y_batch})
                    print("{}\tLast training batch loss: {:.6f}\tAccuracy: {:.2f}%".format(
                        epoch, loss_train, acc_train * 100))
            # If we used early stopping then rollback to the best model found
            if best_params:
                self._restore_model_params(best_params)
            return self

    def predict_proba(self, X):
        if not self._session:
            raise NotFittedError("This %s instance is not fitted yet" % self.__class__.__name__)
        with self._session.as_default() as sess:
            return self._Y_proba.eval(feed_dict={self._X: X})

    def predict(self, X):
        class_indices = np.argmax(self.predict_proba(X), axis=1)
        return np.array([[self.classes_[class_index]]
                         for class_index in class_indices], np.int32)

    def save(self, path):
        self._saver.save(self._session, path)

# %%
dnn_clf = DNNClassifier(random_state=42)
dnn_clf.fit(X_train, y_train, n_epochs=1000, X_valid=X_valid, y_valid=y_valid)
# Out:
# 0	Validation loss: 0.249402	Best loss: 0.249402	Accuracy: 91.14%
# 1	Validation loss: 0.572434	Best loss: 0.249402	Accuracy: 89.95%
# 2	Validation loss: 0.326405	Best loss: 0.249402	Accuracy: 89.95%
# 3	Validation loss: 0.343844	Best loss: 0.249402	Accuracy: 89.95%
# 4	Validation loss: 0.353421	Best loss: 0.249402	Accuracy: 89.95%
# 5	Validation loss: 0.418960	Best loss: 0.249402	Accuracy: 89.95%
# 6	Validation loss: 0.350180	Best loss: 0.249402	Accuracy: 89.95%
# 7	Validation loss: 0.348217	Best loss: 0.249402	Accuracy: 89.95%
# 8	Validation loss: 0.348487	Best loss: 0.249402	Accuracy: 89.95%
# 9	Validation loss: 0.348361	Best loss: 0.249402	Accuracy: 89.95%
# 10	Validation loss: 0.348417	Best loss: 0.249402	Accuracy: 89.95%
# 11	Validation loss: 0.348391	Best loss: 0.249402	Accuracy: 89.95%
# 9	Validation loss: 0.241841	Best loss: 0.238121	Accuracy: 91.20%
# 10	Validation loss: 0.243012	Best loss: 0.238121	Accuracy: 91.14%
# 11	Validation loss: 0.241260	Best loss: 0.238121	Accuracy: 91.23%
# 12	Validation loss: 0.244111	Best loss: 0.238121	Accuracy: 91.15%
# 13	Validation loss: 0.242935	Best loss: 0.238121	Accuracy: 91.12%
# 14	Validation loss: 0.242649	Best loss: 0.238121	Accuracy: 91.11%
# 15	Validation loss: 0.244891	Best loss: 0.238121	Accuracy: 91.08%
# 16	Validation loss: 0.249659	Best loss: 0.238121	Accuracy: 90.85%
# 17	Validation loss: 0.245127	Best loss: 0.238121	Accuracy: 91.03%
# 18	Validation loss: 0.245045	Best loss: 0.238121	Accuracy: 91.02%
# 19	Validation loss: 0.250620	Best loss: 0.238121	Accuracy: 90.98%
# 20	Validation loss: 0.243864	Best loss: 0.238121	Accuracy: 90.92%
# 21	Validation loss: 0.244672	Best loss: 0.238121	Accuracy: 90.96%
# 22	Validation loss: 0.244813	Best loss: 0.238121	Accuracy: 90.98%
# 23	Validation loss: 0.244023	Best loss: 0.238121	Accuracy: 90.97%
# Early stopping!
# RandomizedSearchCV(cv=3, error_score='raise',
#           estimator=DNNClassifier(activation=<function elu at 0x00000214013EE8C8>,
#        batch_norm_momentum=None, batch_size=20, dropout_rate=None,
#        initializer=<tensorflow.python.ops.init_ops.VarianceScaling object at 0x000002141701EBA8>,
#        learning_rate=0.01, n_hidden_layers=5, n_neurons=100,
#        optimizer_class=<class 'tensorflow.python.training.adam.AdamOptimizer'>,
#        random_state=42),
#           fit_params=None, iid=True, n_iter=50, n_jobs=1,
#           param_distributions={'n_neurons': [10, 30, 50, 70, 90, 100, 120, 140, 160], 'batch_size': [10, 50, 100, 500], 'learning_rate': [0.01, 0.02, 0.05, 0.1], 'activation': [<function relu at 0x00000214013FFE18>, <function elu at 0x00000214013EE8C8>, <function leaky_relu.<locals>.parametrized_leaky_relu at 0x0000021426E5F048>, <function leaky_relu.<locals>.parametrized_leaky_relu at 0x0000021426F4A6A8>], 'n_hidden_layers': [2, 3, 4, 5]},
#           pre_dispatch='2*n_jobs', random_state=42, refit=True,
#           return_train_score='warn', scoring=None, verbose=2)

# %%
rnd_search.best_params_
# Out:
# {'n_neurons': 10,
#  'n_hidden_layers': 5,
#  'learning_rate': 0.01,
#  'batch_size': 100,
#  'activation': <function __main__.leaky_relu.<locals>.parametrized_leaky_relu(z, name=None)>}

# %%
rnd_search.best_estimator_.save("DNN after random search")

# %% [markdown]
# ## Ensemble stacking

# %%
lgb_clf = lgb.Booster(model_file='lightbgm original data with 0.899.txt')

# %%
def leaky_relu(alpha=0.01):
    def parametrized_leaky_relu(z, name=None):
        return tf.maximum(alpha * z, z, name=name)
    return parametrized_leaky_relu
dnn_clf = DNNClassifier(random_state=42, n_neurons=10,n_hidden_layers=5,learning_rate=0.01, batch_size=100,activation=leaky_relu(alpha=0.01))
dnn_clf.fit(X_train, y_train, n_epochs=1000, X_valid=X_valid, y_valid=y_valid)
# Out:
# WARNING:tensorflow:From <ipython-input-10-28bac47fa543>:28: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# WARNING:tensorflow:From D:\Anaconda\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# 0	Validation loss: 0.326859	Best loss: 0.326859	Accuracy: 89.95%
# 1	Validation loss: 0.326427	Best loss: 0.326427	Accuracy: 89.95%
# 2	Validation loss: 0.326017	Best loss: 0.326017	Accuracy: 89.95%
# 3	Validation loss: 0.326300	Best loss: 0.326017	Accuracy: 89.95%
# 4	Validation loss: 0.326324	Best loss: 0.326017	Accuracy: 89.95%
# 5	Validation loss: 0.326390	Best loss: 0.326017	Accuracy: 89.95%
# 6	Validation loss: 0.326337	Best loss: 0.326017	Accuracy: 89.95%
# 7	Validation loss: 0.326559	Best loss: 0.326017	Accuracy: 89.95%
# 8	Validation loss: 0.326571	Best loss: 0.326017	Accuracy: 89.95%
# 9	Validation loss: 0.326495	Best loss: 0.326017	Accuracy: 89.95%
# 10	Validation loss: 0.326187	Best loss: 0.326017	Accuracy: 89.95%
# 11	Validation loss: 0.326213	Best loss: 0.326017	Accuracy: 89.95%
# 12	Validation loss: 0.326408	Best loss: 0.326017	Accuracy: 89.95%
# 13	Validation loss: 0.326257	Best loss: 0.326017	Accuracy: 89.95%
# 14	Validation loss: 0.326216	Best loss: 0.326017	Accuracy: 89.95%
# 15	Validation loss: 0.326466	Best loss: 0.326017	Accuracy: 89.95%
# 16	Validation loss: 0.326288	Best loss: 0.326017	Accuracy: 89.95%
# 17	Validation loss: 0.326687	Best loss: 0.326017	Accuracy: 89.95%
# 18	Validation loss: 0.326796	Best loss: 0.326017	Accuracy: 89.95%
# 19	Validation loss: 0.326184	Best loss: 0.326017	Accuracy: 89.95%
# 20	Validation loss: 0.326537	Best loss: 0.326017	Accuracy: 89.95%
# 21	Validation loss: 0.326634	Best loss: 0.326017	Accuracy: 89.95%
# 22	Validation loss: 0.327262	Best loss: 0.326017	Accuracy: 89.95%
# 23	Validation loss: 0.328610	Best loss: 0.326017	Accuracy: 89.95%
# Early stopping!
# DNNClassifier(activation=<function leaky_relu.<locals>.parametrized_leaky_relu at 0x00000113BD111D90>,
#        batch_norm_momentum=None, batch_size=100, dropout_rate=None,
#        initializer=<tensorflow.python.ops.init_ops.VarianceScaling object at 0x00000113A38D9D30>,
#        learning_rate=0.01, n_hidden_layers=5, n_neurons=10,
#        optimizer_class=<class 'tensorflow.python.training.adam.AdamOptimizer'>,
#        random_state=42)

# %%
n_splits = 5 # Number of K-fold Splits
splits = list(StratifiedKFold(n_splits=n_splits, shuffle=True).split(X, y))
predictions = np.zeros(len(X_test))

for i, (train_idx, valid_idx) in enumerate(splits):  
    X_train_predictions = np.empty((32000, 3), dtype=np.float32)
    print(f'Fold {i + 1}')
    #lightBGM training
    x_train = np.array(X)
    y_train = np.array(y)

    trn_data = lgb.Dataset(x_train[train_idx.astype(int)], label=y_train[train_idx.astype(int)])
    val_data = lgb.Dataset(x_train[valid_idx.astype(int)], label=y_train[valid_idx.astype(int)])    
    num_round = 15000
    
    lgb_clf = lgb.train(lgb_param, trn_data, num_round, valid_sets = [trn_data, val_data], verbose_eval=1000, early_stopping_rounds = 250)
    
    X_train_predictions[:, 0] = lgb_clf.predict(trn_data)
    
    #XGboost
    trn_data = xgb.DMatrix(x_train[train_idx.astype(int)], label=y_train[train_idx.astype(int)])
    val_data = xgb.DMatrix(x_train[valid_idx.astype(int)], label=y_train[valid_idx.astype(int)])
    watchlist = [(trn_data, 'train'), (val_data, 'valid')]
    xgb_clf=xgb.train(xgb_param, trn_data, 700, evals=watchlist, early_stopping_rounds=250, verbose_eval=500)
    X_train_predictions[:, 1] = xgb_clf.predict(trn_data)
    
    #DNN
    dnn_clf = DNNClassifier(random_state=42, n_neurons=10,n_hidden_layers=5,learning_rate=0.01, 
                            batch_size=100,activation=leaky_relu(alpha=0.01))
    dnn_clf.fit(x_train[train_idx.astype(int)], y_train[train_idx.astype(int)], n_epochs=1000, 
                X_valid=x_train[valid_idx.astype(int)], y_valid=y_train[valid_idx.astype(int)])
    trn_data=x_train[valid_idx.astype(int)]
    X_train_predictions[:, 2] = dnn_clf.predict(trn_data).ravel()
    
    #Stack with RF
    rnd_forest_blender = RandomForestClassifier(n_estimators=200, oob_score=True, random_state=42)
    rnd_forest_blender.fit(X_train_predictions, y_train[train_idx.astype(int)])
    
    oof[valid_idx] =  rnd_forest_blender.predict(x_train[valid_idx])
    
    
    # Prediction
    X_test_predictions = np.empty((len(X_test), 3), dtype=np.float32)
    X_test_predictions[:, 0] = lgb_clf.predict(X_test)
    xgb_test = xgb.DMatrix(X_test)
    X_test_predictions[:, 1] = xgb_clf.predict(xgb_test)
    X_test_predictions[:, 2] = dnn_clf.predict(X_test).ravel()
    
    predictions += rnd_forest_blender.predict(X_test_predictions)/5

print("CV score: {:<8.5f}".format(roc_auc_score(y, oof)))
# Out:
# Fold 1
# Training until validation scores don't improve for 250 rounds.
# [1000]	training's auc: 0.863042	valid_1's auc: 0.846143
# [2000]	training's auc: 0.891049	valid_1's auc: 0.871905
# [3000]	training's auc: 0.903758	valid_1's auc: 0.882893
# [4000]	training's auc: 0.91159	valid_1's auc: 0.889249
# [5000]	training's auc: 0.916991	valid_1's auc: 0.89308
# [6000]	training's auc: 0.920833	valid_1's auc: 0.895317
# [7000]	training's auc: 0.924171	valid_1's auc: 0.896886
# [8000]	training's auc: 0.927212	valid_1's auc: 0.897698
# [9000]	training's auc: 0.930283	valid_1's auc: 0.898212
# Early stopping, best iteration is:
# [9468]	training's auc: 0.93173	valid_1's auc: 0.898429
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-77-ad5e98b0822d> in <module>
#      16     lgb_clf = lgb.train(lgb_param, trn_data, num_round, valid_sets = [trn_data, val_data], verbose_eval=1000, early_stopping_rounds = 250)
#      17
# ---> 18     X_train_predictions[:, 0] = lgb_clf.predict(trn_data)
#      19
#      20     #XGboost
#
# D:\Anaconda\lib\site-packages\lightgbm\basic.py in predict(self, data, num_iteration, raw_score, pred_leaf, pred_contrib, data_has_header, is_reshape, **kwargs)
#    2201         return predictor.predict(data, num_iteration,
#    2202                                  raw_score, pred_leaf, pred_contrib,
# -> 2203                                  data_has_header, is_reshape)
#    2204
#    2205     def refit(self, data, label, decay_rate=0.9, **kwargs):
#
# D:\Anaconda\lib\site-packages\lightgbm\basic.py in predict(self, data, num_iteration, raw_score, pred_leaf, pred_contrib, data_has_header, is_reshape)
#     433         """
#     434         if isinstance(data, Dataset):
# --> 435             raise TypeError("Cannot use Dataset instance for prediction, please use raw data instead")
#     436         data = _data_from_pandas(data, None, None, self.pandas_categorical)[0]
#     437         predict_type = C_API_PREDICT_NORMAL
#
# TypeError: Cannot use Dataset instance for prediction, please use raw data instead

# %%
X_train_predictions = np.empty((len(X_train), 3), dtype=np.float32)
X_train_predictions[:, 0] = lgb_clf.predict(X_train)

# %%
xgb_train = xgb.DMatrix(X_train)
X_train_predictions[:, 1] = xgb_clf.predict(xgb_train)

# %%
X_train_predictions[:, 2] = dnn_clf.predict(X_train).ravel()

# %%
from sklearn.ensemble import RandomForestClassifier
rnd_forest_blender = RandomForestClassifier(n_estimators=200, oob_score=True, random_state=42)
rnd_forest_blender.fit(X_train_predictions, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=200, n_jobs=1,
#             oob_score=True, random_state=42, verbose=0, warm_start=False)

# %%
X_val_predictions = np.empty((len(X_valid), 3), dtype=np.float32)
X_val_predictions[:, 0] = lgb_clf.predict(X_valid)

# %%
xgb_val = xgb.DMatrix(X_valid)
X_val_predictions[:, 1] = xgb_clf.predict(xgb_val)

# %%
X_val_predictions[:, 2] = dnn_clf.predict(X_valid).ravel()

# %%
y_pred = rnd_forest_blender.predict(X_val_predictions)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_valid, y_pred)
# Out:
# 0.960575

# %%
y_proba = rnd_forest_blender.predict_proba(X_val_predictions)

# %% [markdown]
# ## Submission

# %%
X_test_predictions = np.empty((len(X_test), 3), dtype=np.float32)
X_test_predictions[:, 0] = lgb_clf.predict(X_test)

# %%
submission=pd.DataFrame()
submission['ID_code']=test['ID_code']
def generate_submission(pred, submission):
    submission['target']=pred
    submision.to_csv('submission.csv', index=False)
    return submission
